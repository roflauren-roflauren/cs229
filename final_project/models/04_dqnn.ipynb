# %% [markdown]
# # IMPORTS

# %%
import random as rd
import pandas as pd 
import numpy  as np
import util 

import torch
import torch.nn as nn 
import torch.nn.functional as F

# %% [markdown]
# # CONSTANTS

# %%
# network sizing:
NUM_INPUTS       = 144 + 1  # num. network inputs.
NUM_OUTPUTS      = 2        # num. network outputs (1 per state, i.e. bet home/away).
N_ODDS_PER_TEAM  = 72       # num. odds figures per team. 

# hyperparam grid search ranges, substitute values as necessary: 
# eta_options              = [1e-2, 1e-3, 1e-4]
# epsilon_options          = [0.3, 0.5, 0.7]
# num_exps_to_copy_options = [10000, 20000, 50000]

# hyperparameters: 
eta              = 1e-3     # optimizer learning rate.
epsilon          = 0.3
num_exps_to_copy = 20000    # num. exps. per train/target network sync.

# fixed vals:
discount_factor  = 0.95     # discount factor for rl update.
max_train_eps    = 1000     # max. number of training episodes.

# %% [markdown]
# # NEURAL NETWORK CLASS

# %%
# class to represent the deep, fully-connected neural network: 
class DeepQNN(nn.Module): 
    def __init__(self):
        super().__init__()
        # instantiate the model, which consists of a three layer 
        # (input-hidden-output) structure. 
        self.ll1 = nn.Linear(NUM_INPUTS, NUM_INPUTS)
        self.ll2 = nn.Linear(NUM_INPUTS, NUM_INPUTS)
        self.ll3 = nn.Linear(NUM_INPUTS, NUM_INPUTS)
        self.ll4 = nn.Linear(NUM_INPUTS, NUM_OUTPUTS)
        
        # initialize layers: 
        nn.init.xavier_uniform_(self.ll1.weight)
        nn.init.xavier_uniform_(self.ll2.weight)
        nn.init.xavier_uniform_(self.ll3.weight)
        nn.init.xavier_uniform_(self.ll4.weight)
    
    def forward(self, state):
        x1  = F.relu(self.ll1(state))
        x2  = F.relu(self.ll2(x1))
        x3  = F.relu(self.ll3(x2))
        out = self.ll4(x3)
        return out

# %% [markdown]
# # DATA

# %%
# load data:
x_train, y_train = util.load_dataset('../data/xy_train_data.csv')

# state generator function: 
def get_curr_and_next_state():
    # track idx: 
    idx = 0
    while idx < len(x_train):
        # get current state and final winner odds: 
        curr_state, curr_lbl = x_train[idx], y_train[idx]
        final_winner_odds = curr_state[-1] if curr_lbl == 1 else curr_state[N_ODDS_PER_TEAM - 1]
        # get some random next state, it doesn't matter: 
        rd.seed(229)
        next_state_idx = rd.randint(0, len(x_train) - 1)
        next_state, next_lbl = x_train[next_state_idx], y_train[next_state_idx]
        # yield result: 
        yield (curr_state, next_state, curr_lbl, next_lbl, final_winner_odds)
        # increment the index: 
        idx += 1  
    
# ex. of how to use the generator: 
# state_gen = get_curr_and_next_state()
# curr_state, next_state, curr_lbl, next_lbl = next(state_gen)

# %% [markdown]
# # TRAINING LOOP SET-UP

# %%
# take over any available gpus: 
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# init. the networks. convert to float. 
train_net, target_net = DeepQNN().to(device).float(), DeepQNN().to(device).float()

# init. optimizer: 
optimizer = torch.optim.SGD(train_net.parameters(), lr=eta)

# init. loss fn: 
loss_fn = nn.MSELoss()

# track total experiences: 
num_exps = 0

# %%
# make sure CUDA is available: 
print(device)
# Out:
# cuda

# %% [markdown]
# # MAIN TRAINING LOOP

# %%
# copy epsilon var: 
e = epsilon

# main training loop: 
for ep_idx in range(max_train_eps):
    
    # refresh loss log, balance, state generator:  
    loss_log = []
    balance = 6000     
    state_gen = get_curr_and_next_state()
    
    # episode concludes when balance <= 0 or all training states visited: 
    while (balance > 0):
        
        # acquire next state: 
        curr_state, next_state, curr_lbl, next_lbl, final_winner_odds = next(state_gen, (None, None, None, None, None))
        
        # only proceed with training if next training state is
        # non-visited (i.e., != None): 
        if curr_state is not None: 
            
            # STATE: concatenate the balance to `curr_state` to make the 
            # complete state vector and convert to tensor:
            curr_state = np.append(curr_state, [balance])
            curr_state = torch.from_numpy(curr_state).to(device)
            
            # ACTION: generate action (i.e., team to bet on and assoc. 
            # pred. prob from 0 to 1) for this state using `target_net`:
            
            # first compute q-val of each action (i.e., logits for betting
            # home or away, output from sigmoid): 
            q_vals = target_net(curr_state.float()).cpu().data.numpy()
            
            # normalize q-vals to produce prediction probabilities: 
            tot = sum(q_vals)
            pred_probs = [q_val / tot for q_val in q_vals]
            
            # identify the bet-upon team: 
            pred_team = np.argmax(pred_probs)
            
            # apply epsilon-greedy: 
            epsilon_prob = np.random.uniform()
            if epsilon_prob < e: 
                pred_team = rd.randint(0, 1)
            
            # extract associated `pred_prob``:
            pred_prob = pred_probs[pred_team]
        
            # REWARD: compute reward (i.e., winnings/losings) depending on 
            # `pred_prob` and whether `pred_team` == `curr_lbl`:   
            reward = 0
            pred_multiplier = (pred_prob - 0.5) / 0.5 if pred_prob >= 0.5 else -1 * (pred_prob - 0.5) / 0.5
            
            if pred_team == curr_lbl: 
                winnings = final_winner_odds * pred_multiplier if final_winner_odds >= 0 else 100 * pred_multiplier
                reward   = winnings
                balance += winnings  
            else: 
                losings  = 100 * pred_multiplier if final_winner_odds >= 0 else abs(final_winner_odds) * pred_multiplier
                reward   = -1 * losings
                balance -= losings
            
            # NEXT STATE: concatenate the updated balance to the next
            # state array and convert to tensor: 
            next_state = np.append(next_state, [balance])
            next_state = torch.from_numpy(next_state).to(device)
            
            # STATE TERMINAL: state is terminal if balance <= 0:
            terminal = 1 if balance <= 0 else 0 
            
            # UPDATE NETWORK WEIGHTS: determine max q-value assoc. with
            # next state and use as target value for q-update. 
            
            # re-compute q-vals for current episode: 
            q_vals = train_net(curr_state.float())
            
            # compute the maximum q-vals for next state: 
            max_sp_q_val = target_net(next_state.float()).max(-1).values 
            
            # compute the q-update target value:
            targets = reward + (1 - terminal) * discount_factor * max_sp_q_val
            # argets = torch.from_numpy(np.asarray([reward])).float().to(device)
            
            # update the q-values to only retain those corresponding to 
            # the executed action (i.e., which team was bet upon): 
            action_mask = F.one_hot(torch.tensor(np.array([pred_team], dtype='int64'), device=device), num_classes=2)
            # apply mask and collapse tensor for scalar comps: 
            q_vals = (action_mask * q_vals).sum(-1) 
             
            # compute loss and backprop! 
            loss = loss_fn(q_vals, targets.detach().view(1))
            optimizer.zero_grad()
            loss.backward()
            # clip gradients to prevent exploding loss:
            torch.nn.utils.clip_grad_norm_(train_net.parameters(), 1.)
            optimizer.step()
            
            # record loss: 
            loss_log.append(loss)
            
            # update experience count: 
            num_exps += 1 
            
            # copy training network weights to target network if 
            # `num_exps_to_copy` reached: 
            if num_exps % num_exps_to_copy == 0: 
                print('syncing network weights...')
                target_net.load_state_dict(train_net.state_dict())
        
        # if all training states visited, break current loop:  
        else:     
            break 
    
    # report episode count, final balance, avg. loss:
    # if ep_idx % 50 == 0:
    print(f'episode {ep_idx}: ending balance :: {balance:.2f}, average exp. loss :: {sum(loss_log) / len(loss_log):.2e}')
    
    # decay epsilon before next training episode if it is still above 
    # some threshold: 
    if e > 0.05:
        e -= -0.001
            
# save model parameters: 
print('saving model parameters...')
torch.save(target_net.state_dict(), './trained_dqnn.params')
# Out:
# episode 0: ending balance :: -17204.37, average exp. loss :: 1.76e+06
# episode 1: ending balance :: -25335.67, average exp. loss :: 3.97e+06
# episode 2: ending balance :: -809.14, average exp. loss :: 1.46e+05
# episode 3: ending balance :: -1141.31, average exp. loss :: 1.38e+05
# episode 4: ending balance :: -68376.94, average exp. loss :: 1.73e+07
# episode 5: ending balance :: -330.03, average exp. loss :: 1.21e+05
# episode 6: ending balance :: -83.98, average exp. loss :: 9.45e+04
# episode 7: ending balance :: -251.94, average exp. loss :: 8.01e+04
# episode 8: ending balance :: -37.29, average exp. loss :: 2.44e+05
# episode 9: ending balance :: -2089.93, average exp. loss :: 2.23e+05
# episode 10: ending balance :: -15973.20, average exp. loss :: 1.55e+06
# episode 11: ending balance :: -17692.82, average exp. loss :: 1.71e+06
# episode 12: ending balance :: -127413.62, average exp. loss :: 5.91e+07
# episode 13: ending balance :: -291.67, average exp. loss :: 5.23e+04
# episode 14: ending balance :: -158785.46, average exp. loss :: 9.02e+07
# episode 15: ending balance :: -3480.19, average exp. loss :: 1.25e+05
# episode 16: ending balance :: -1579.78, average exp. loss :: 1.02e+05
# episode 17: ending balance :: 4837541.87, average exp. loss :: 4.13e+09
# episode 18: ending balance :: -9388.30, average exp. loss :: 5.67e+05
# episode 19: ending balance :: -4564.11, average exp. loss :: 1.76e+05
# episode 20: ending balance :: -1020.92, average exp. loss :: 6.78e+05
# episode 21: ending balance :: -70.17, average exp. loss :: 4.70e+04
# episode 22: ending balance :: -1216.46, average exp. loss :: 2.99e+05
# episode 23: ending balance :: -33754.09, average exp. loss :: 5.10e+06
# episode 24: ending balance :: -2494.42, average exp. loss :: 1.12e+05
# episode 25: ending balance :: -227.99, average exp. loss :: 1.16e+05
# episode 26: ending balance :: -276.90, average exp. loss :: 8.75e+04
# episode 27: ending balance :: -131.08, average exp. loss :: 3.47e+04
# episode 28: ending balance :: -513.51, average exp. loss :: 7.14e+04
# episode 29: ending balance :: -104.37, average exp. loss :: 9.42e+04
# episode 30: ending balance :: -484.06, average exp. loss :: 3.84e+04
# episode 31: ending balance :: -98246.25, average exp. loss :: 1.58e+07
# episode 32: ending balance :: -2608.60, average exp. loss :: 1.00e+05
# episode 33: ending balance :: -998.25, average exp. loss :: 1.58e+05
# episode 34: ending balance :: -139072.37, average exp. loss :: 6.95e+07
# episode 35: ending balance :: -48869.76, average exp. loss :: 9.74e+06
# episode 36: ending balance :: -17172.32, average exp. loss :: 1.73e+06
# episode 37: ending balance :: -24965.99, average exp. loss :: 1.53e+07
# episode 38: ending balance :: -134757.29, average exp. loss :: 6.52e+07
# episode 39: ending balance :: -620.80, average exp. loss :: 9.82e+04
# episode 40: ending balance :: -2348434.16, average exp. loss :: 2.97e+09
# episode 41: ending balance :: -131.91, average exp. loss :: 4.72e+04
# syncing network weights...
# episode 42: ending balance :: -149.18, average exp. loss :: 1.33e+05
# episode 43: ending balance :: -1542.30, average exp. loss :: 4.04e+05
# episode 44: ending balance :: 26034.00, average exp. loss :: 4.17e+04
# episode 45: ending balance :: -137455.95, average exp. loss :: 1.85e+08
# episode 46: ending balance :: -7363.25, average exp. loss :: 1.67e+06
# episode 47: ending balance :: -646.03, average exp. loss :: 5.32e+05
# episode 48: ending balance :: -261200.20, average exp. loss :: 6.49e+08
# episode 49: ending balance :: -15329.01, average exp. loss :: 3.84e+06
# episode 50: ending balance :: -1855.63, average exp. loss :: 4.27e+05
# episode 51: ending balance :: 33429.60, average exp. loss :: 2.43e+04
# episode 52: ending balance :: -299019.25, average exp. loss :: 6.49e+08
# episode 53: ending balance :: -14297.34, average exp. loss :: 4.33e+05
# episode 54: ending balance :: -95.87, average exp. loss :: 1.75e+05
# syncing network weights...
# episode 55: ending balance :: -197849.79, average exp. loss :: 1.01e+07
# episode 56: ending balance :: -61559.20, average exp. loss :: 3.48e+07
# episode 57: ending balance :: -112.70, average exp. loss :: 3.63e+05
# episode 58: ending balance :: -683.91, average exp. loss :: 5.73e+05
# episode 59: ending balance :: -328.90, average exp. loss :: 4.01e+05
# episode 60: ending balance :: -8937.14, average exp. loss :: 2.14e+06
# episode 61: ending balance :: -785.51, average exp. loss :: 5.84e+05
# episode 62: ending balance :: -3643.36, average exp. loss :: 1.12e+06
# episode 63: ending balance :: -1616.02, average exp. loss :: 7.02e+05
# episode 64: ending balance :: -374.70, average exp. loss :: 3.08e+05
# episode 65: ending balance :: -4491.86, average exp. loss :: 1.26e+06
# episode 66: ending balance :: -1036.10, average exp. loss :: 6.15e+05
# episode 67: ending balance :: -115.60, average exp. loss :: 2.53e+05
# episode 68: ending balance :: -26.10, average exp. loss :: 1.61e+05
# episode 69: ending balance :: -451.46, average exp. loss :: 2.16e+05
# episode 70: ending balance :: -186960.67, average exp. loss :: 2.65e+08
# episode 71: ending balance :: -59.02, average exp. loss :: 1.85e+05
# episode 72: ending balance :: -995.59, average exp. loss :: 7.31e+05
# episode 73: ending balance :: -657.77, average exp. loss :: 5.53e+05
# episode 74: ending balance :: -459.49, average exp. loss :: 2.13e+05
# episode 75: ending balance :: -3044.75, average exp. loss :: 1.02e+06
# episode 76: ending balance :: -7599.40, average exp. loss :: 2.19e+05
# episode 77: ending balance :: -351.62, average exp. loss :: 1.91e+05
# episode 78: ending balance :: -76.79, average exp. loss :: 4.65e+05
# episode 79: ending balance :: -54249.61, average exp. loss :: 2.53e+07
# episode 80: ending balance :: -3313.88, average exp. loss :: 3.51e+05
# episode 81: ending balance :: -292.94, average exp. loss :: 1.85e+05
# episode 82: ending balance :: -3070973.28, average exp. loss :: 3.23e+09
# episode 83: ending balance :: -4520.76, average exp. loss :: 1.92e+05
# episode 84: ending balance :: -149482.50, average exp. loss :: 1.69e+08
# episode 85: ending balance :: -963.69, average exp. loss :: 7.18e+05
# episode 86: ending balance :: -542.30, average exp. loss :: 5.90e+05
# episode 87: ending balance :: -1376.53, average exp. loss :: 6.41e+05
# episode 88: ending balance :: -514.49, average exp. loss :: 5.24e+05
# episode 89: ending balance :: -97.67, average exp. loss :: 3.13e+05
# episode 90: ending balance :: -6284.81, average exp. loss :: 1.29e+06
# episode 91: ending balance :: -353398.46, average exp. loss :: 1.18e+09
# episode 92: ending balance :: -120.17, average exp. loss :: 4.71e+05
# episode 93: ending balance :: -213.72, average exp. loss :: 9.75e+04
# episode 94: ending balance :: -183237.17, average exp. loss :: 1.52e+07
# episode 95: ending balance :: -1244.76, average exp. loss :: 6.12e+05
# episode 96: ending balance :: -1014.54, average exp. loss :: 7.07e+05
# episode 97: ending balance :: -90230.16, average exp. loss :: 6.85e+07
# episode 98: ending balance :: -575.46, average exp. loss :: 5.20e+05
# episode 99: ending balance :: -458065.45, average exp. loss :: 1.50e+09
# episode 100: ending balance :: -9080.78, average exp. loss :: 2.09e+06
# episode 101: ending balance :: -323.95, average exp. loss :: 1.78e+05
# episode 102: ending balance :: -1798.32, average exp. loss :: 6.89e+05
# episode 103: ending balance :: -457.24, average exp. loss :: 1.48e+05
# episode 104: ending balance :: -231.05, average exp. loss :: 4.73e+05
# episode 105: ending balance :: -880.70, average exp. loss :: 6.83e+05
# episode 106: ending balance :: -496.36, average exp. loss :: 4.17e+05
# episode 107: ending balance :: -703.83, average exp. loss :: 6.55e+05
# syncing network weights...
# episode 108: ending balance :: -36380.01, average exp. loss :: 9.53e+05
# episode 109: ending balance :: -40182.39, average exp. loss :: 1.55e+06
# episode 110: ending balance :: -1002.78, average exp. loss :: 7.99e+05
# episode 111: ending balance :: -97.72, average exp. loss :: 2.28e+05
# episode 112: ending balance :: -330.78, average exp. loss :: 2.06e+05
# episode 113: ending balance :: -1984.65, average exp. loss :: 1.29e+06
# episode 114: ending balance :: -4147.40, average exp. loss :: 1.95e+06
# episode 115: ending balance :: -5392.49, average exp. loss :: 2.61e+06
# episode 116: ending balance :: -5600.76, average exp. loss :: 1.50e+06
# episode 117: ending balance :: -28636.80, average exp. loss :: 1.26e+07
# episode 118: ending balance :: -4848.91, average exp. loss :: 2.30e+06
# episode 119: ending balance :: -16159.58, average exp. loss :: 5.20e+06
# episode 120: ending balance :: -4876.19, average exp. loss :: 2.30e+06
# episode 121: ending balance :: -2746.87, average exp. loss :: 8.67e+05
# episode 122: ending balance :: -4327.63, average exp. loss :: 2.01e+06
# episode 123: ending balance :: -15562.29, average exp. loss :: 4.91e+06
# episode 124: ending balance :: -2380.81, average exp. loss :: 7.99e+05
# episode 125: ending balance :: -4551.94, average exp. loss :: 2.12e+06
# episode 126: ending balance :: -5152.46, average exp. loss :: 2.44e+06
# episode 127: ending balance :: -6511.32, average exp. loss :: 2.14e+06
# episode 128: ending balance :: -25.28, average exp. loss :: 2.77e+05
# episode 129: ending balance :: -1041.93, average exp. loss :: 7.61e+05
# episode 130: ending balance :: -4187.37, average exp. loss :: 1.93e+06
# episode 131: ending balance :: -99342.07, average exp. loss :: 1.06e+08
# episode 132: ending balance :: -51.46, average exp. loss :: 2.56e+05
# episode 133: ending balance :: -854.77, average exp. loss :: 7.16e+05
# episode 134: ending balance :: -6128.46, average exp. loss :: 1.76e+05
# episode 135: ending balance :: -4133.31, average exp. loss :: 1.14e+06
# episode 136: ending balance :: -6745.54, average exp. loss :: 1.75e+06
# episode 137: ending balance :: -9383.74, average exp. loss :: 2.52e+06
# episode 138: ending balance :: -19760.70, average exp. loss :: 6.96e+06
# episode 139: ending balance :: -1608.71, average exp. loss :: 2.15e+05
# episode 140: ending balance :: -671087.88, average exp. loss :: 4.23e+09
# episode 141: ending balance :: -5290.80, average exp. loss :: 2.49e+06
# episode 142: ending balance :: -19486.62, average exp. loss :: 6.80e+06
# episode 143: ending balance :: -3190.86, average exp. loss :: 1.45e+06
# episode 144: ending balance :: -182992.95, average exp. loss :: 3.35e+08
# episode 145: ending balance :: -97670.39, average exp. loss :: 1.02e+08
# episode 146: ending balance :: -10572.73, average exp. loss :: 3.10e+06
# episode 147: ending balance :: -19881.88, average exp. loss :: 6.98e+06
# episode 148: ending balance :: -3534.09, average exp. loss :: 1.59e+06
# episode 149: ending balance :: -41507.94, average exp. loss :: 1.66e+06
# episode 150: ending balance :: -3167.76, average exp. loss :: 9.22e+05
# episode 151: ending balance :: -13998.45, average exp. loss :: 2.71e+06
# episode 152: ending balance :: -19737.97, average exp. loss :: 6.91e+06
# episode 153: ending balance :: -21411.67, average exp. loss :: 7.79e+06
# episode 154: ending balance :: -1449.55, average exp. loss :: 6.94e+05
# episode 155: ending balance :: -23095.04, average exp. loss :: 8.71e+06
# episode 156: ending balance :: -19567.86, average exp. loss :: 6.81e+06
# episode 157: ending balance :: -24.19, average exp. loss :: 2.11e+05
# episode 158: ending balance :: -21294.90, average exp. loss :: 7.73e+06
# episode 159: ending balance :: -29357.89, average exp. loss :: 1.26e+07
# episode 160: ending balance :: -5665.24, average exp. loss :: 1.45e+06
# episode 161: ending balance :: -516.31, average exp. loss :: 2.88e+05
# episode 162: ending balance :: -4885.41, average exp. loss :: 2.25e+06
# episode 163: ending balance :: -114762.37, average exp. loss :: 1.06e+08
# episode 164: ending balance :: -8838.37, average exp. loss :: 2.31e+06
# episode 165: ending balance :: -9196.25, average exp. loss :: 2.69e+06
# episode 166: ending balance :: -19471.57, average exp. loss :: 6.74e+06
# episode 167: ending balance :: -176.78, average exp. loss :: 3.91e+05
# episode 168: ending balance :: -35684.46, average exp. loss :: 1.73e+07
# episode 169: ending balance :: -40628.47, average exp. loss :: 1.70e+07
# episode 634: ending balance :: -16975.69, average exp. loss :: 8.71e+05
# episode 635: ending balance :: -21007.58, average exp. loss :: 2.70e+06
# episode 636: ending balance :: -39417.57, average exp. loss :: 7.73e+06
# episode 637: ending balance :: -4106.35, average exp. loss :: 7.22e+05
# episode 638: ending balance :: -1080.89, average exp. loss :: 4.58e+05
# episode 639: ending balance :: -99524.66, average exp. loss :: 1.40e+07
# episode 640: ending balance :: -2013.60, average exp. loss :: 6.73e+05
# episode 641: ending balance :: -6965.85, average exp. loss :: 1.68e+06
# episode 642: ending balance :: -5817.83, average exp. loss :: 1.13e+06
# syncing network weights...
# episode 643: ending balance :: -6046.69, average exp. loss :: 5.31e+05
# episode 644: ending balance :: -961.39, average exp. loss :: 2.37e+06
# episode 645: ending balance :: -961.39, average exp. loss :: 2.36e+06
# episode 646: ending balance :: -961.39, average exp. loss :: 2.36e+06
# episode 647: ending balance :: -961.39, average exp. loss :: 2.35e+06
# episode 648: ending balance :: -961.39, average exp. loss :: 2.35e+06
# episode 649: ending balance :: -961.39, average exp. loss :: 2.35e+06
# episode 650: ending balance :: -961.39, average exp. loss :: 2.35e+06
# episode 651: ending balance :: -961.39, average exp. loss :: 2.35e+06
# episode 652: ending balance :: -961.39, average exp. loss :: 2.34e+06
# episode 653: ending balance :: -961.39, average exp. loss :: 2.34e+06
# episode 654: ending balance :: -961.39, average exp. loss :: 2.34e+06
# episode 655: ending balance :: -961.39, average exp. loss :: 2.33e+06
# episode 656: ending balance :: -961.39, average exp. loss :: 2.33e+06
# episode 657: ending balance :: -961.39, average exp. loss :: 2.33e+06
# episode 658: ending balance :: -961.39, average exp. loss :: 2.33e+06
# episode 659: ending balance :: -961.39, average exp. loss :: 2.32e+06
# episode 660: ending balance :: -961.39, average exp. loss :: 2.32e+06
# episode 661: ending balance :: -961.39, average exp. loss :: 2.32e+06
# episode 662: ending balance :: -961.39, average exp. loss :: 2.31e+06
# episode 663: ending balance :: -961.39, average exp. loss :: 2.31e+06
# episode 664: ending balance :: -961.39, average exp. loss :: 2.31e+06
# episode 665: ending balance :: -961.39, average exp. loss :: 2.31e+06
# episode 666: ending balance :: -961.39, average exp. loss :: 2.31e+06
# episode 667: ending balance :: -961.39, average exp. loss :: 2.30e+06
# episode 668: ending balance :: -961.39, average exp. loss :: 2.30e+06
# episode 669: ending balance :: -961.39, average exp. loss :: 2.30e+06
# episode 670: ending balance :: -961.39, average exp. loss :: 2.30e+06
# episode 671: ending balance :: -961.39, average exp. loss :: 2.29e+06
# episode 672: ending balance :: -961.39, average exp. loss :: 2.29e+06
# episode 673: ending balance :: -961.39, average exp. loss :: 2.29e+06
# episode 674: ending balance :: -961.39, average exp. loss :: 2.29e+06
# ...
# episode 772: ending balance :: -961.39, average exp. loss :: 2.14e+06
# episode 773: ending balance :: -961.39, average exp. loss :: 2.13e+06
# episode 774: ending balance :: -961.39, average exp. loss :: 2.13e+06
# episode 775: ending balance :: -961.39, average exp. loss :: 2.13e+06
# episode 776: ending balance :: -961.39, average exp. loss :: 2.13e+06
# episode 777: ending balance :: -961.39, average exp. loss :: 2.13e+06
# episode 778: ending balance :: -961.39, average exp. loss :: 2.13e+06
# episode 779: ending balance :: -961.39, average exp. loss :: 2.12e+06
# episode 780: ending balance :: -961.39, average exp. loss :: 2.12e+06
# episode 781: ending balance :: -961.39, average exp. loss :: 2.12e+06
# episode 782: ending balance :: -961.39, average exp. loss :: 2.12e+06
# episode 783: ending balance :: -961.39, average exp. loss :: 2.12e+06
# episode 784: ending balance :: -961.39, average exp. loss :: 2.12e+06
# episode 785: ending balance :: -961.39, average exp. loss :: 2.12e+06
# episode 786: ending balance :: -961.39, average exp. loss :: 2.12e+06
# episode 787: ending balance :: -961.39, average exp. loss :: 2.12e+06
# episode 788: ending balance :: -961.39, average exp. loss :: 2.12e+06
# episode 789: ending balance :: -961.39, average exp. loss :: 2.11e+06
# episode 790: ending balance :: -961.39, average exp. loss :: 2.11e+06
# episode 791: ending balance :: -961.39, average exp. loss :: 2.11e+06
# episode 792: ending balance :: -961.39, average exp. loss :: 2.11e+06
# episode 793: ending balance :: -961.39, average exp. loss :: 2.11e+06
# episode 794: ending balance :: -961.39, average exp. loss :: 2.11e+06
# episode 795: ending balance :: -961.39, average exp. loss :: 2.11e+06
# episode 796: ending balance :: -961.39, average exp. loss :: 2.10e+06
# episode 797: ending balance :: -961.39, average exp. loss :: 2.11e+06
# episode 798: ending balance :: -961.39, average exp. loss :: 2.10e+06
# episode 799: ending balance :: -961.39, average exp. loss :: 2.10e+06
# episode 800: ending balance :: -961.39, average exp. loss :: 2.10e+06
# episode 801: ending balance :: -961.39, average exp. loss :: 2.10e+06
# episode 802: ending balance :: -961.39, average exp. loss :: 2.10e+06
# episode 803: ending balance :: -961.39, average exp. loss :: 2.10e+06
# episode 804: ending balance :: -961.39, average exp. loss :: 2.09e+06
# episode 805: ending balance :: -961.39, average exp. loss :: 2.10e+06
# episode 806: ending balance :: -961.39, average exp. loss :: 2.09e+06
# episode 807: ending balance :: -961.39, average exp. loss :: 2.09e+06
# episode 808: ending balance :: -961.39, average exp. loss :: 2.09e+06
# episode 809: ending balance :: -961.39, average exp. loss :: 2.09e+06
# episode 810: ending balance :: -961.39, average exp. loss :: 2.09e+06
# episode 811: ending balance :: -961.39, average exp. loss :: 2.09e+06
# episode 812: ending balance :: -961.39, average exp. loss :: 2.09e+06
# episode 813: ending balance :: -961.39, average exp. loss :: 2.09e+06
# episode 814: ending balance :: -961.39, average exp. loss :: 2.09e+06
# episode 815: ending balance :: -961.39, average exp. loss :: 2.08e+06
# episode 816: ending balance :: -961.39, average exp. loss :: 2.09e+06
# episode 817: ending balance :: -961.39, average exp. loss :: 2.08e+06
# episode 818: ending balance :: -961.39, average exp. loss :: 2.08e+06
# episode 819: ending balance :: -961.39, average exp. loss :: 2.08e+06
# episode 820: ending balance :: -961.39, average exp. loss :: 2.07e+06
# episode 821: ending balance :: -961.39, average exp. loss :: 2.07e+06
# episode 822: ending balance :: -961.39, average exp. loss :: 2.07e+06
# episode 823: ending balance :: -961.39, average exp. loss :: 2.07e+06
# episode 824: ending balance :: -961.39, average exp. loss :: 2.07e+06
# episode 825: ending balance :: -961.39, average exp. loss :: 2.07e+06
# episode 826: ending balance :: -961.39, average exp. loss :: 2.06e+06
# episode 827: ending balance :: -961.39, average exp. loss :: 2.07e+06
# episode 828: ending balance :: -961.39, average exp. loss :: 2.06e+06
# episode 829: ending balance :: -961.39, average exp. loss :: 2.06e+06
# episode 830: ending balance :: -961.39, average exp. loss :: 2.06e+06
# episode 831: ending balance :: -961.39, average exp. loss :: 2.06e+06
# episode 832: ending balance :: -961.39, average exp. loss :: 2.06e+06
# episode 833: ending balance :: -961.39, average exp. loss :: 2.06e+06
# episode 834: ending balance :: -961.39, average exp. loss :: 2.06e+06
# episode 835: ending balance :: -961.39, average exp. loss :: 2.06e+06
# episode 836: ending balance :: -961.39, average exp. loss :: 2.06e+06
# episode 837: ending balance :: -961.39, average exp. loss :: 2.06e+06
# episode 838: ending balance :: -961.39, average exp. loss :: 2.05e+06
# episode 839: ending balance :: -961.39, average exp. loss :: 2.05e+06
# episode 840: ending balance :: -961.39, average exp. loss :: 2.05e+06
# episode 841: ending balance :: -961.39, average exp. loss :: 2.05e+06
# episode 842: ending balance :: -961.39, average exp. loss :: 2.05e+06
# episode 843: ending balance :: -961.39, average exp. loss :: 2.05e+06
# episode 844: ending balance :: -961.39, average exp. loss :: 2.05e+06
# episode 845: ending balance :: -961.39, average exp. loss :: 2.05e+06
# episode 846: ending balance :: -961.39, average exp. loss :: 2.05e+06
# episode 847: ending balance :: -961.39, average exp. loss :: 2.05e+06
# episode 848: ending balance :: -961.39, average exp. loss :: 2.04e+06
# episode 849: ending balance :: -961.39, average exp. loss :: 2.05e+06
# episode 850: ending balance :: -961.39, average exp. loss :: 2.04e+06
# episode 851: ending balance :: -961.39, average exp. loss :: 2.05e+06
# episode 852: ending balance :: -961.39, average exp. loss :: 2.04e+06
# episode 853: ending balance :: -961.39, average exp. loss :: 2.04e+06
# episode 854: ending balance :: -961.39, average exp. loss :: 2.04e+06
# episode 855: ending balance :: -961.39, average exp. loss :: 2.04e+06
# episode 856: ending balance :: -961.39, average exp. loss :: 2.04e+06
# episode 857: ending balance :: -961.39, average exp. loss :: 2.04e+06
# episode 858: ending balance :: -961.39, average exp. loss :: 2.04e+06
# episode 859: ending balance :: -961.39, average exp. loss :: 2.04e+06
# episode 860: ending balance :: -961.39, average exp. loss :: 2.04e+06
# episode 861: ending balance :: -961.39, average exp. loss :: 2.04e+06
# episode 862: ending balance :: -961.39, average exp. loss :: 2.03e+06
# episode 863: ending balance :: -961.39, average exp. loss :: 2.03e+06
# episode 864: ending balance :: -961.39, average exp. loss :: 2.03e+06
# episode 865: ending balance :: -961.39, average exp. loss :: 2.03e+06
# episode 866: ending balance :: -961.39, average exp. loss :: 2.03e+06
# episode 867: ending balance :: -961.39, average exp. loss :: 2.03e+06
# episode 868: ending balance :: -961.39, average exp. loss :: 2.03e+06
# episode 869: ending balance :: -961.39, average exp. loss :: 2.02e+06
# episode 870: ending balance :: -961.39, average exp. loss :: 2.02e+06
# episode 871: ending balance :: -961.39, average exp. loss :: 2.02e+06
# episode 872: ending balance :: -961.39, average exp. loss :: 2.03e+06
# episode 873: ending balance :: -961.39, average exp. loss :: 2.02e+06
# episode 874: ending balance :: -961.39, average exp. loss :: 2.02e+06
# episode 875: ending balance :: -961.39, average exp. loss :: 2.02e+06
# episode 876: ending balance :: -961.39, average exp. loss :: 2.02e+06
# episode 877: ending balance :: -961.39, average exp. loss :: 2.02e+06
# episode 878: ending balance :: -961.39, average exp. loss :: 2.02e+06
# episode 879: ending balance :: -961.39, average exp. loss :: 2.02e+06
# episode 880: ending balance :: -961.39, average exp. loss :: 2.02e+06
# episode 881: ending balance :: -961.39, average exp. loss :: 2.01e+06
# episode 882: ending balance :: -961.39, average exp. loss :: 2.02e+06
# episode 883: ending balance :: -961.39, average exp. loss :: 2.01e+06
# episode 884: ending balance :: -961.39, average exp. loss :: 2.02e+06
# episode 885: ending balance :: -961.39, average exp. loss :: 2.01e+06
# episode 886: ending balance :: -961.39, average exp. loss :: 2.01e+06
# episode 887: ending balance :: -961.39, average exp. loss :: 2.01e+06
# episode 888: ending balance :: -961.39, average exp. loss :: 2.01e+06
# episode 889: ending balance :: -961.39, average exp. loss :: 2.00e+06
# episode 890: ending balance :: -961.39, average exp. loss :: 2.00e+06
# episode 891: ending balance :: -961.39, average exp. loss :: 2.00e+06
# episode 892: ending balance :: -961.39, average exp. loss :: 2.00e+06
# episode 893: ending balance :: -961.39, average exp. loss :: 2.00e+06
# episode 894: ending balance :: -961.39, average exp. loss :: 2.00e+06
# episode 895: ending balance :: -961.39, average exp. loss :: 2.00e+06
# episode 896: ending balance :: -961.39, average exp. loss :: 2.00e+06
# episode 897: ending balance :: -961.39, average exp. loss :: 2.00e+06
# episode 898: ending balance :: -961.39, average exp. loss :: 2.00e+06
# episode 899: ending balance :: -961.39, average exp. loss :: 2.00e+06
# episode 900: ending balance :: -961.39, average exp. loss :: 2.00e+06
# episode 901: ending balance :: -961.39, average exp. loss :: 1.99e+06
# episode 902: ending balance :: -961.39, average exp. loss :: 1.99e+06
# episode 903: ending balance :: -961.39, average exp. loss :: 1.99e+06
# episode 904: ending balance :: -961.39, average exp. loss :: 1.99e+06
# episode 905: ending balance :: -961.39, average exp. loss :: 1.99e+06
# episode 906: ending balance :: -961.39, average exp. loss :: 1.98e+06
# episode 907: ending balance :: -961.39, average exp. loss :: 1.98e+06
# episode 908: ending balance :: -961.39, average exp. loss :: 1.98e+06
# episode 909: ending balance :: -961.39, average exp. loss :: 1.98e+06
# episode 910: ending balance :: -961.39, average exp. loss :: 1.99e+06
# episode 911: ending balance :: -961.39, average exp. loss :: 1.98e+06
# episode 912: ending balance :: -961.39, average exp. loss :: 1.98e+06
# episode 913: ending balance :: -961.39, average exp. loss :: 1.98e+06
# episode 914: ending balance :: -961.39, average exp. loss :: 1.98e+06
# episode 915: ending balance :: -961.39, average exp. loss :: 1.98e+06
# episode 916: ending balance :: -961.39, average exp. loss :: 1.98e+06
# episode 917: ending balance :: -961.39, average exp. loss :: 1.98e+06
# episode 918: ending balance :: -961.39, average exp. loss :: 1.98e+06
# episode 919: ending balance :: -961.39, average exp. loss :: 1.98e+06
# episode 920: ending balance :: -961.39, average exp. loss :: 1.98e+06
# episode 921: ending balance :: -961.39, average exp. loss :: 1.98e+06
# episode 922: ending balance :: -961.39, average exp. loss :: 1.97e+06
# episode 923: ending balance :: -961.39, average exp. loss :: 1.97e+06
# episode 924: ending balance :: -961.39, average exp. loss :: 1.97e+06
# episode 925: ending balance :: -961.39, average exp. loss :: 1.97e+06
# episode 926: ending balance :: -961.39, average exp. loss :: 1.97e+06
# episode 927: ending balance :: -961.39, average exp. loss :: 1.97e+06
# episode 928: ending balance :: -961.39, average exp. loss :: 1.97e+06
# episode 929: ending balance :: -961.39, average exp. loss :: 1.97e+06
# episode 930: ending balance :: -961.39, average exp. loss :: 1.97e+06
# episode 931: ending balance :: -961.39, average exp. loss :: 1.96e+06
# episode 932: ending balance :: -961.39, average exp. loss :: 1.96e+06
# episode 933: ending balance :: -961.39, average exp. loss :: 1.96e+06
# episode 934: ending balance :: -961.39, average exp. loss :: 1.97e+06
# episode 935: ending balance :: -961.39, average exp. loss :: 1.97e+06
# episode 936: ending balance :: -961.39, average exp. loss :: 1.96e+06
# episode 937: ending balance :: -961.39, average exp. loss :: 1.97e+06
# episode 938: ending balance :: -961.39, average exp. loss :: 1.96e+06
# episode 939: ending balance :: -961.39, average exp. loss :: 1.96e+06
# episode 940: ending balance :: -961.39, average exp. loss :: 1.96e+06
# episode 941: ending balance :: -961.39, average exp. loss :: 1.96e+06
# episode 942: ending balance :: -961.39, average exp. loss :: 1.96e+06
# episode 943: ending balance :: -961.39, average exp. loss :: 1.96e+06
# episode 944: ending balance :: -961.39, average exp. loss :: 1.96e+06
# episode 945: ending balance :: -961.39, average exp. loss :: 1.95e+06
# episode 946: ending balance :: -961.39, average exp. loss :: 1.96e+06
# episode 947: ending balance :: -961.39, average exp. loss :: 1.95e+06
# episode 948: ending balance :: -961.39, average exp. loss :: 1.95e+06
# episode 949: ending balance :: -961.39, average exp. loss :: 1.95e+06
# episode 950: ending balance :: -961.39, average exp. loss :: 1.95e+06
# episode 951: ending balance :: -961.39, average exp. loss :: 1.95e+06
# episode 952: ending balance :: -961.39, average exp. loss :: 1.95e+06
# episode 953: ending balance :: -961.39, average exp. loss :: 1.94e+06
# episode 954: ending balance :: -961.39, average exp. loss :: 1.95e+06
# episode 955: ending balance :: -961.39, average exp. loss :: 1.95e+06
# episode 956: ending balance :: -961.39, average exp. loss :: 1.95e+06
# episode 957: ending balance :: -961.39, average exp. loss :: 1.95e+06
# episode 958: ending balance :: -961.39, average exp. loss :: 1.94e+06
# episode 959: ending balance :: -961.39, average exp. loss :: 1.94e+06
# episode 960: ending balance :: -961.39, average exp. loss :: 1.94e+06
# episode 961: ending balance :: -961.39, average exp. loss :: 1.94e+06
# episode 962: ending balance :: -961.39, average exp. loss :: 1.94e+06
# episode 963: ending balance :: -961.39, average exp. loss :: 1.94e+06
# episode 964: ending balance :: -961.39, average exp. loss :: 1.94e+06
# episode 965: ending balance :: -961.39, average exp. loss :: 1.93e+06
# episode 966: ending balance :: -961.39, average exp. loss :: 1.93e+06
# episode 967: ending balance :: -961.39, average exp. loss :: 1.93e+06
# episode 968: ending balance :: -961.39, average exp. loss :: 1.93e+06
# episode 969: ending balance :: -961.39, average exp. loss :: 1.93e+06
# episode 970: ending balance :: -961.39, average exp. loss :: 1.93e+06
# episode 971: ending balance :: -961.39, average exp. loss :: 1.93e+06
# episode 972: ending balance :: -961.39, average exp. loss :: 1.93e+06
# episode 973: ending balance :: -961.39, average exp. loss :: 1.93e+06
# episode 974: ending balance :: -961.39, average exp. loss :: 1.93e+06
# episode 975: ending balance :: -961.39, average exp. loss :: 1.93e+06
# episode 976: ending balance :: -961.39, average exp. loss :: 1.93e+06
# episode 977: ending balance :: -961.39, average exp. loss :: 1.92e+06
# episode 978: ending balance :: -961.39, average exp. loss :: 1.92e+06
# episode 979: ending balance :: -961.39, average exp. loss :: 1.92e+06
# episode 980: ending balance :: -961.39, average exp. loss :: 1.92e+06
# episode 981: ending balance :: -961.39, average exp. loss :: 1.92e+06
# episode 982: ending balance :: -961.39, average exp. loss :: 1.92e+06
# episode 983: ending balance :: -961.39, average exp. loss :: 1.92e+06
# episode 984: ending balance :: -961.39, average exp. loss :: 1.92e+06
# episode 985: ending balance :: -961.39, average exp. loss :: 1.91e+06
# episode 986: ending balance :: -961.39, average exp. loss :: 1.92e+06
# episode 987: ending balance :: -961.39, average exp. loss :: 1.92e+06
# episode 988: ending balance :: -961.39, average exp. loss :: 1.91e+06
# episode 989: ending balance :: -961.39, average exp. loss :: 1.91e+06
# episode 990: ending balance :: -961.39, average exp. loss :: 1.91e+06
# episode 991: ending balance :: -961.39, average exp. loss :: 1.91e+06
# episode 992: ending balance :: -961.39, average exp. loss :: 1.91e+06
# episode 993: ending balance :: -961.39, average exp. loss :: 1.91e+06
# episode 994: ending balance :: -961.39, average exp. loss :: 1.91e+06
# episode 995: ending balance :: -961.39, average exp. loss :: 1.91e+06
# episode 996: ending balance :: -961.39, average exp. loss :: 1.91e+06
# episode 997: ending balance :: -961.39, average exp. loss :: 1.91e+06
# episode 998: ending balance :: -961.39, average exp. loss :: 1.91e+06
# episode 999: ending balance :: -961.39, average exp. loss :: 1.90e+06
# saving model parameters...

# %% [markdown]
# # VALIDATION/TEST SET EVALUATION

# %%
# load model from file if necessary:
trained_model = DeepQNN().to(device=device)
trained_model.load_state_dict(torch.load('./trained_dqnn.params'))
# Out:
# <All keys matched successfully>

# %%
# comment/uncomment following lines as necessary if using 
# validation or test set. 
# x_test, y_test = util.load_dataset('../data/xy_valid_data.csv', True)
x_test, y_test = util.load_dataset('../data/xy_test_data.csv', True)

balance = 1000

preds = []
picks = []

for entry_idx in range(len(x_test)):
    # extract entry:
    curr_state, curr_lbl = x_test[entry_idx], y_test[entry_idx]
    final_winner_odds = curr_state[-1] if curr_lbl == 1 else curr_state[N_ODDS_PER_TEAM - 1]
    
    # compute q-vals & normalize for probs:
    curr_state = np.append(curr_state, [balance])
    curr_state = torch.from_numpy(curr_state).to(device)
    
    q_vals = trained_model(curr_state.float()).cpu().data.numpy()
    
    tot = sum(q_vals)
    pred_probs = [q_val / tot for q_val in q_vals]
    
    # identify the bet-upon team: 
    pred_team = np.argmax(pred_probs)
        
    # extract associated `pred_prob``:
    pred_prob = pred_probs[pred_team]

    # REWARD: compute reward (i.e., winnings/losings) depending on 
    # `pred_prob` and whether `pred_team` == `curr_lbl`:   
    reward = 0
    pred_multiplier = (pred_prob - 0.5) / 0.5 if pred_prob >= 0.5 else -1 * (pred_prob - 0.5) / 0.5
    
    if pred_team == curr_lbl: 
        winnings = final_winner_odds * pred_multiplier if final_winner_odds >= 0 else 100 * pred_multiplier
        reward   = winnings
        balance += winnings  
    else: 
        losings  = 100 * pred_multiplier if final_winner_odds >= 0 else abs(final_winner_odds) * pred_multiplier
        reward   = -1 * losings
        balance -= losings
    
    preds.append(pred_prob)
    picks.append(pred_team)

# %%
# convert picks from 0/1 to 'home'/'away':
picks = ['away' if pick == 1. else 'home' for pick in picks]

# %%
# re-map probs. if pick is home to maintain prob. multiplier 
# computation code as defined for logreg model:
for idx, (pred, pick) in enumerate(zip(preds, picks)): 
    if pick == 'home': 
        preds[idx] = (preds[idx] - 1) / -2

# %%
test = pd.read_csv('../data/test_data.csv')

# add `probs` column to dataframe:
test['preds'] = preds

# add the picks column to the dataframe:
test['strategy_picks'] = picks

# data preview:
test.head(5)
# Out:
#    home_avg_odds_hr_0  home_avg_odds_hr_1  home_avg_odds_hr_2  \
# 0               110.0              -110.0               100.0
# 1              -200.0              -200.0              -200.0
# 2               160.0               140.0               140.0
# 3              -190.0              -190.0              -180.0
# 4              -140.0              -140.0              -140.0
#
#    home_avg_odds_hr_3  home_avg_odds_hr_4  home_avg_odds_hr_5  \
# 0               110.0               110.0               110.0
# 1              -200.0              -190.0              -160.0
# 2               140.0               140.0               140.0
# 3              -180.0              -170.0              -170.0
# 4              -140.0              -140.0              -140.0
#
#    home_avg_odds_hr_6  home_avg_odds_hr_7  home_avg_odds_hr_8  \
# 0               110.0               110.0               110.0
# 1              -150.0              -170.0              -200.0
# 2               140.0               140.0               140.0
# 3              -170.0              -170.0              -180.0
# 4              -150.0              -140.0              -140.0
#
#    home_avg_odds_hr_9  ...  away_avg_odds_hr_68  away_avg_odds_hr_69  \
# 0               110.0  ...                190.0                190.0
# 1              -200.0  ...                280.0                270.0
# 2               140.0  ...                150.0                150.0
# 3              -190.0  ...                420.0                420.0
# 4              -140.0  ...                400.0                400.0
#
#    away_avg_odds_hr_70  away_avg_odds_hr_71  winner  favorite  \
# 0                190.0                190.0    away      home
# 1                270.0                280.0    home      home
# 2                140.0                140.0    away      away
# 3                420.0                400.0    home      home
# 4                400.0                400.0    home      home
#
#    has_favorite_for_winner  closely_contested     preds  strategy_picks
# 0                    False               True -0.127835            home
# 1                     True              False -2.515982            home
# 2                    False               True  0.108200            home
# 3                     True              False -0.875530            home
# 4                     True              False -0.428443            home
#
# [5 rows x 150 columns]

# %%
# drop any unnecessary columns: 
test = test[['home_avg_odds_hr_71', 'away_avg_odds_hr_71', 'winner', 'favorite', 'has_favorite_for_winner', 'closely_contested', 'strategy_picks', 'preds']]

# create a winner_avg_odds column: 
test['winner_avg_odds_hr_71'] = np.where(
    test['winner'] == 'home', test['home_avg_odds_hr_71'], test['away_avg_odds_hr_71']
)

# create 'relative_underdog' column: 
test['relative_underdog'] = np.where(
    test['favorite'] == 'home', 'away', 'home'
)

# %%
N_PROFITABLE_BETS = 0
N_TOTAL_BETS      = 0

NET_VALUE_OF_BETS_WON  = []
NET_VALUE_OF_BETS_LOST = []

UNDERDOG_BETS_HITS  = []
N_UNDERDOG_BETS_TOTAL = 0

CLEAR_WINNER_BETS_HITS = []
N_CLEAR_WINNER_BETS_TOTAL = 0

CLOSELY_CONTESTED_BETS_HITS = []
N_CLOSELY_CONTESTED_BETS_TOTAL = 0

balance = 1000

# iterate through dataframe: 
for row in test.itertuples(index=False):
    
    # if there is balance remaining: 
    if balance >= 0:
    
        # extract elements: 
        final_home_odds, final_away_odds, winner, favorite, has_favorite_for_winner, \
            closely_contested, strategy_pick, pred_prob, final_winner_odds, relative_underdog = row
            
         # update counts:
        if has_favorite_for_winner: N_CLEAR_WINNER_BETS_TOTAL += 1
        if closely_contested: N_CLOSELY_CONTESTED_BETS_TOTAL += 1
        
        # compute `pred` multiplier:
        # if betting on away (pred = [0.5, 1.0]), mulitplier = (pred - 0.5) / 0.5
        # if betting on home (pred = [0.0, 0.5)), multiplier = -1 * (pred - 0.5) / 0.5
        if pred_prob >= 0.5:
            pred_multiplier = (pred_prob - 0.5) / 0.5
        else: 
            pred_multiplier = -1 * (pred_prob - 0.5) / 0.5
        
        # if strategy bet on underdog: 
        if strategy_pick == relative_underdog: 
            N_UNDERDOG_BETS_TOTAL += 1
        
        # if pick was correct: 
        if winner == strategy_pick:
            N_PROFITABLE_BETS += 1
            
            if final_winner_odds >= 0: 
                NET_VALUE_OF_BETS_WON.append(final_winner_odds * pred_multiplier)
            if final_winner_odds < 0:
                NET_VALUE_OF_BETS_WON.append(100 * pred_multiplier)
            
            # if strategy correctly bet on underdog:
            if strategy_pick == relative_underdog:
                if final_winner_odds >= 0: 
                    UNDERDOG_BETS_HITS.append(final_winner_odds * pred_multiplier)
                if final_winner_odds < 0:
                    UNDERDOG_BETS_HITS.append(100 * pred_multiplier)
                    
            # if the strategy correctly bet in a 'clear winner' match:
            if has_favorite_for_winner:
                if final_winner_odds >= 0: 
                    CLEAR_WINNER_BETS_HITS.append(final_winner_odds * pred_multiplier)
                if final_winner_odds < 0:
                    CLEAR_WINNER_BETS_HITS.append(100 * pred_multiplier)
                    
            # if the strategy correctly bet in a 'closely contested' match:
            if closely_contested: 
                if final_winner_odds >= 0: 
                    CLOSELY_CONTESTED_BETS_HITS.append(final_winner_odds * pred_multiplier)
                if final_winner_odds < 0:
                    CLOSELY_CONTESTED_BETS_HITS.append(100 * pred_multiplier) 
                    
            # update balance: 
            if final_winner_odds >= 0: 
                balance += final_winner_odds * pred_multiplier
            if final_winner_odds < 0:
                balance += 100  * pred_multiplier
                                
        # if the pick was incorrect:
        elif winner != strategy_pick:
            if final_winner_odds >= 0: 
                NET_VALUE_OF_BETS_LOST.append(100 * pred_multiplier)
            if final_winner_odds < 0:
                NET_VALUE_OF_BETS_LOST.append(abs(final_winner_odds) * pred_multiplier)
                
            # update balance: 
            if final_winner_odds >= 0: 
                balance -= 100 * pred_multiplier
            if final_winner_odds < 0:
                balance -= abs(final_winner_odds) * pred_multiplier
                
        # update total bet count:
        N_TOTAL_BETS += 1

# %%
profitable_bet_rate       = N_PROFITABLE_BETS / N_TOTAL_BETS
overall_profit            = sum(NET_VALUE_OF_BETS_WON) - sum(NET_VALUE_OF_BETS_LOST)
largest_amt_won           = max(NET_VALUE_OF_BETS_WON)
smallest_amt_won          = min(NET_VALUE_OF_BETS_WON)
avg_amt_won               = sum(NET_VALUE_OF_BETS_WON) / len(NET_VALUE_OF_BETS_WON)
avg_amt_loss              = sum(NET_VALUE_OF_BETS_LOST) / len(NET_VALUE_OF_BETS_LOST)

underdog_bet_hr           = len(UNDERDOG_BETS_HITS) / N_UNDERDOG_BETS_TOTAL  if (N_UNDERDOG_BETS_TOTAL > 0) else 'no underdog bets made.'
avg_underdog_hit_winnings = sum(UNDERDOG_BETS_HITS) / len(UNDERDOG_BETS_HITS) if len(UNDERDOG_BETS_HITS) > 0 else 'no winning underdog bets made.'

clearwinner_bet_hr           = len(CLEAR_WINNER_BETS_HITS) / N_CLEAR_WINNER_BETS_TOTAL  if (N_CLEAR_WINNER_BETS_TOTAL > 0) else 'no clear favorite bets made.'
avg_clearwinner_hit_winnings = sum(CLEAR_WINNER_BETS_HITS) / len(CLEAR_WINNER_BETS_HITS) if len(CLEAR_WINNER_BETS_HITS) > 0 else 'no winning clear favorite bets made.'

closelycontested_bet_hr           = len(CLOSELY_CONTESTED_BETS_HITS) / N_CLOSELY_CONTESTED_BETS_TOTAL  if (N_CLOSELY_CONTESTED_BETS_TOTAL > 0) else 'no closely contested bets made.'
avg_closelycontested_hit_winnings = sum(CLOSELY_CONTESTED_BETS_HITS) / len(CLOSELY_CONTESTED_BETS_HITS) if len(CLOSELY_CONTESTED_BETS_HITS) > 0 else 'no winning closely contested bets made.'


metrics = {
    'profitable_bet_rate' : f'{profitable_bet_rate:.2f} ({N_PROFITABLE_BETS} / {N_TOTAL_BETS})',
    'overall_profit' : overall_profit,
    'largest_amt_won' : largest_amt_won,
    'smallest_amt_won' : smallest_amt_won,
    'avg_amt_won' : avg_amt_won,
    'avg_amt_loss' : avg_amt_loss,
    'underdog_bet_hr' : underdog_bet_hr, 
    'avg_underdog_hit_winnings' : avg_underdog_hit_winnings, 
    'clearwinner_bet_hr' : clearwinner_bet_hr,
    'avg_clearwinner_hit_winnings' : avg_clearwinner_hit_winnings,
    'closelycontested_bet_hr' : closelycontested_bet_hr,
    'avg_closelycontested_hit_winnings' : avg_closelycontested_hit_winnings
}

# report metrics
for metric in metrics.keys():    
    if type(metrics[metric]) is str: 
        print(f'{metric} :: {metrics[metric]}')
    else: 
        print(f'{metric} :: {metrics[metric]:.2f}')
# Out:
# profitable_bet_rate :: 0.61 (57 / 94)
# overall_profit :: -1667.23
# largest_amt_won :: 1323.90
# smallest_amt_won :: 29.30
# avg_amt_won :: 141.57
# avg_amt_loss :: 263.15
# underdog_bet_hr :: 0.45
# avg_underdog_hit_winnings :: 242.35
# clearwinner_bet_hr :: 0.68
# avg_clearwinner_hit_winnings :: 199.11
# closelycontested_bet_hr :: 0.55
# avg_closelycontested_hit_winnings :: 76.49
