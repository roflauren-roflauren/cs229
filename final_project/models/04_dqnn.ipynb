# %% [markdown]
# # IMPORTS

# %%
import random as rd
import pandas as pd 
import numpy  as np
import util 

import torch
import torch.nn as nn 
import torch.nn.functional as F

# %% [markdown]
# # CONSTANTS

# %%
# network sizing:
NUM_INPUTS       = 144 + 1  # num. network inputs.
NUM_OUTPUTS      = 2        # num. network outputs (1 per state, i.e. bet home/away).
N_ODDS_PER_TEAM  = 72       # num. odds figures per team. 

# hyperparam grid search ranges, substitute values as necessary: 
# eta_options              = [1e-2, 1e-3, 1e-4]
# epsilon_options          = [0.3, 0.5, 0.7]
# num_exps_to_copy_options = [10000, 20000, 50000]
# discount_factor_options  = [0.95, 0.99]

# hyperparameters: 
eta              = 1e-3     # optimizer learning rate.
epsilon          = 0.5
num_exps_to_copy = 20000    # num. exps. per train/target network sync.

# fixed vals:
discount_factor  = 0.99     # discount factor for rl update.
max_train_eps    = 1000     # max. number of training episodes.

# %% [markdown]
# # NEURAL NETWORK CLASS

# %%
# class to represent the deep, fully-connected neural network: 
class DeepQNN(nn.Module): 
    def __init__(self):
        super().__init__()
        # instantiate the model, which consists of a three layer 
        # (input-hidden-output) structure. 
        self.ll1 = nn.Linear(NUM_INPUTS, NUM_INPUTS)
        self.ll2 = nn.Linear(NUM_INPUTS, NUM_OUTPUTS)
        
        # initialize layers: 
        nn.init.xavier_uniform_(self.ll1.weight)
        nn.init.xavier_uniform_(self.ll2.weight)
    
    def forward(self, state):
        x1  = F.relu(self.ll1(state))
        out = self.ll2(x1)
        return out

# %% [markdown]
# # DATA

# %%
# load data:
x_train, y_train = util.load_dataset('../data/xy_train_data.csv')

# state generator function: 
def get_curr_and_next_state():
    # track idx: 
    idx = 0
    while idx < len(x_train):
        # get current state and final winner odds: 
        curr_state, curr_lbl = x_train[idx], y_train[idx]
        final_winner_odds = curr_state[-1] if curr_lbl == 1 else curr_state[N_ODDS_PER_TEAM - 1]
        # get some random next state, it doesn't matter: 
        rd.seed(229)
        next_state_idx = rd.randint(0, len(x_train) - 1)
        next_state, next_lbl = x_train[next_state_idx], y_train[next_state_idx]
        # yield result: 
        yield (curr_state, next_state, curr_lbl, next_lbl, final_winner_odds)
        # increment the index: 
        idx += 1  
    
# ex. of how to use the generator: 
# state_gen = get_curr_and_next_state()
# curr_state, next_state, curr_lbl, next_lbl = next(state_gen)

# %% [markdown]
# # TRAINING LOOP SET-UP

# %%
# take over any available gpus: 
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# init. the networks. convert to float. 
train_net, target_net = DeepQNN().to(device).float(), DeepQNN().to(device).float()

# init. optimizer: 
optimizer = torch.optim.SGD(train_net.parameters(), lr=eta)

# init. loss fn: 
loss_fn = nn.MSELoss()

# track total experiences: 
num_exps = 0

# %%
# make sure CUDA is available: 
print(device)
# Out:
# cuda

# %% [markdown]
# # MAIN TRAINING LOOP

# %%
# copy epsilon var: 
e = epsilon

# main training loop: 
for ep_idx in range(max_train_eps):
    
    # refresh loss log, balance, state generator:  
    loss_log = []
    balance = 6000     
    state_gen = get_curr_and_next_state()
    
    # episode concludes when balance <= 0 or all training states visited: 
    while (balance > 0):
        
        # acquire next state: 
        curr_state, next_state, curr_lbl, next_lbl, final_winner_odds = next(state_gen, (None, None, None, None, None))
        
        # only proceed with training if next training state is
        # non-visited (i.e., != None): 
        if curr_state is not None: 
            
            # STATE: concatenate the balance to `curr_state` to make the 
            # complete state vector and convert to tensor:
            curr_state = np.append(curr_state, [balance])
            curr_state = torch.from_numpy(curr_state).to(device)
            
            # ACTION: generate action (i.e., team to bet on and assoc. 
            # pred. prob from 0 to 1) for this state using `target_net`:
            
            # first compute q-val of each action (i.e., logits for betting
            # home or away, output from sigmoid): 
            q_vals = train_net(curr_state.float()).cpu().data.numpy()
            
            # normalize q-vals to produce prediction probabilities: 
            tot = sum(q_vals)
            pred_probs = [q_val / tot for q_val in q_vals]
            
            # identify the bet-upon team: 
            pred_team = np.argmax(pred_probs)
            
            # apply epsilon-greedy: 
            epsilon_prob = np.random.uniform()
            if epsilon_prob < e: 
                pred_team = rd.randint(0, 1)
            
            # extract associated `pred_prob``:
            pred_prob = pred_probs[pred_team]
        
            # REWARD: compute reward (i.e., winnings/losings) depending on 
            # `pred_prob` and whether `pred_team` == `curr_lbl`:   
            reward = 0
            pred_multiplier = (pred_prob - 0.5) / 0.5 if pred_prob >= 0.5 else -1 * (pred_prob - 0.5) / 0.5
            
            if pred_team == curr_lbl: 
                winnings = final_winner_odds * pred_multiplier if final_winner_odds >= 0 else 100 * pred_multiplier
                reward   = winnings
                balance += winnings  
            else: 
                losings  = 100 * pred_multiplier if final_winner_odds >= 0 else abs(final_winner_odds) * pred_multiplier
                reward   = -1 * losings
                balance -= losings
            
            # NEXT STATE: concatenate the updated balance to the next
            # state array and convert to tensor: 
            next_state = np.append(next_state, [balance])
            next_state = torch.from_numpy(next_state).to(device)
            
            # STATE TERMINAL: state is terminal if balance <= 0:
            terminal = 1 if balance <= 0 else 0 
            
            # UPDATE NETWORK WEIGHTS: determine max q-value assoc. with
            # next state and use as target value for q-update. 
            
            # re-compute q-vals for current episode: 
            q_vals = train_net(curr_state.float())
            
            # compute the maximum q-vals for next state: 
            max_sp_q_val = target_net(next_state.float()).max(-1).values 
            
            # compute the q-update target value:
            targets = reward + (1 - terminal) * discount_factor * max_sp_q_val
            # argets = torch.from_numpy(np.asarray([reward])).float().to(device)
            
            # update the q-values to only retain those corresponding to 
            # the executed action (i.e., which team was bet upon): 
            action_mask = F.one_hot(torch.tensor(np.array([pred_team], dtype='int64'), device=device), num_classes=2)
            # apply mask and collapse tensor for scalar comps: 
            q_vals = (action_mask * q_vals).sum(-1) 
             
            # compute loss and backprop! 
            loss = loss_fn(q_vals, targets.detach().view(1))
            optimizer.zero_grad()
            loss.backward()
            # clip gradients to prevent exploding loss:
            torch.nn.utils.clip_grad_norm_(train_net.parameters(), 1.)
            optimizer.step()
            
            # record loss: 
            loss_log.append(loss)
            
            # update experience count: 
            num_exps += 1 
            
            # copy training network weights to target network if 
            # `num_exps_to_copy` reached: 
            if num_exps % num_exps_to_copy == 0: 
                print('syncing network weights...')
                target_net.load_state_dict(train_net.state_dict())
        
        # if all training states visited, break current loop:  
        else:     
            break 
    
    # report episode count, final balance, avg. loss:
    # if ep_idx % 50 == 0:
    print(f'episode {ep_idx}: ending balance :: {balance:.2f}, average exp. loss :: {sum(loss_log) / len(loss_log):.2e}')
    
    # decay epsilon before next training episode if it is still above 
    # some threshold: 
    if e > 0.05:
        e -= -0.001
            
# save model parameters: 
print('saving model parameters...')
torch.save(target_net.state_dict(), './trained_dqnn.params')
# Out:
# episode 0: ending balance :: -16667.98, average exp. loss :: 1.59e+06
# episode 1: ending balance :: -11725.09, average exp. loss :: 1.17e+06
# episode 2: ending balance :: -6386.59, average exp. loss :: 3.05e+06
# episode 3: ending balance :: -109528.64, average exp. loss :: 5.15e+06
# episode 4: ending balance :: -12638.79, average exp. loss :: 3.86e+06
# episode 5: ending balance :: -15377.80, average exp. loss :: 4.93e+06
# episode 6: ending balance :: 28037.23, average exp. loss :: 1.00e+05
# episode 7: ending balance :: -9897.12, average exp. loss :: 5.74e+05
# episode 8: ending balance :: -12057.60, average exp. loss :: 1.18e+06
# episode 9: ending balance :: -2278.51, average exp. loss :: 1.28e+05
# episode 10: ending balance :: -24.17, average exp. loss :: 1.43e+05
# episode 11: ending balance :: -1391.27, average exp. loss :: 2.26e+05
# episode 12: ending balance :: -5534.86, average exp. loss :: 2.33e+05
# syncing network weights...
# episode 13: ending balance :: 50741.94, average exp. loss :: 1.84e+06
# episode 14: ending balance :: -1289.79, average exp. loss :: 1.59e+05
# episode 15: ending balance :: -12508.18, average exp. loss :: 5.46e+06
# episode 16: ending balance :: -35225.95, average exp. loss :: 3.34e+06
# episode 17: ending balance :: -2316.37, average exp. loss :: 6.37e+05
# episode 18: ending balance :: -1645.08, average exp. loss :: 4.98e+05
# episode 19: ending balance :: -5821.10, average exp. loss :: 2.56e+05
# episode 20: ending balance :: -314.04, average exp. loss :: 8.85e+05
# episode 21: ending balance :: -1337.90, average exp. loss :: 2.78e+05
# episode 22: ending balance :: -4511.87, average exp. loss :: 4.74e+05
# episode 23: ending balance :: -13.19, average exp. loss :: 3.29e+05
# episode 24: ending balance :: -678.65, average exp. loss :: 2.53e+05
# episode 25: ending balance :: 223769.83, average exp. loss :: 4.56e+06
# episode 26: ending balance :: -80237.52, average exp. loss :: 3.55e+08
# episode 27: ending balance :: -1500.03, average exp. loss :: 4.02e+06
# episode 28: ending balance :: -5389.78, average exp. loss :: 7.12e+05
# episode 29: ending balance :: -9311.04, average exp. loss :: 6.07e+05
# episode 30: ending balance :: -51633.50, average exp. loss :: 2.51e+06
# episode 31: ending balance :: -1795.02, average exp. loss :: 4.22e+05
# episode 32: ending balance :: -1786.68, average exp. loss :: 7.28e+05
# episode 33: ending balance :: -190353.79, average exp. loss :: 7.77e+08
# syncing network weights...
# episode 34: ending balance :: -233.83, average exp. loss :: 2.46e+06
# episode 35: ending balance :: -1090.99, average exp. loss :: 1.16e+06
# episode 36: ending balance :: -1733.15, average exp. loss :: 2.13e+06
# episode 37: ending balance :: -55094.46, average exp. loss :: 9.64e+08
# episode 38: ending balance :: -225362.40, average exp. loss :: 1.35e+10
# episode 39: ending balance :: 169493.81, average exp. loss :: 8.84e+06
# episode 40: ending balance :: -11284.41, average exp. loss :: 3.99e+06
# episode 41: ending balance :: -613.30, average exp. loss :: 3.26e+06
# episode 42: ending balance :: -10781.54, average exp. loss :: 6.55e+07
# episode 43: ending balance :: -45241.26, average exp. loss :: 1.03e+08
# episode 44: ending balance :: -38697.42, average exp. loss :: 3.20e+06
# episode 45: ending balance :: -36272.94, average exp. loss :: 5.74e+07
# episode 46: ending balance :: -11550.56, average exp. loss :: 2.81e+07
# episode 47: ending balance :: -28278.68, average exp. loss :: 1.07e+07
# episode 48: ending balance :: -140610.13, average exp. loss :: 2.03e+09
# episode 49: ending balance :: -1084.67, average exp. loss :: 1.58e+06
# episode 50: ending balance :: -38186.44, average exp. loss :: 5.12e+08
# syncing network weights...
# episode 51: ending balance :: 47827.05, average exp. loss :: 2.14e+06
# episode 52: ending balance :: -29064.84, average exp. loss :: 9.26e+06
# episode 53: ending balance :: -252445.87, average exp. loss :: 1.53e+08
# episode 54: ending balance :: -71084.03, average exp. loss :: 1.76e+07
# episode 55: ending balance :: 431274.33, average exp. loss :: 4.95e+07
# episode 56: ending balance :: -3639.03, average exp. loss :: 1.64e+06
# episode 57: ending balance :: -789.58, average exp. loss :: 1.32e+06
# episode 58: ending balance :: -9813.62, average exp. loss :: 1.03e+07
# episode 59: ending balance :: 199391.00, average exp. loss :: 1.09e+07
# episode 60: ending balance :: -782768.30, average exp. loss :: 6.18e+08
# episode 61: ending balance :: -344.54, average exp. loss :: 2.41e+06
# syncing network weights...
# episode 62: ending balance :: -13735.91, average exp. loss :: 6.99e+06
# episode 63: ending balance :: -514983.17, average exp. loss :: 8.75e+07
# episode 64: ending balance :: -1922756.93, average exp. loss :: 2.96e+09
# episode 65: ending balance :: -204.62, average exp. loss :: 7.51e+06
# episode 66: ending balance :: -52105.75, average exp. loss :: 2.29e+08
# episode 67: ending balance :: -2924.37, average exp. loss :: 4.40e+06
# syncing network weights...
# episode 68: ending balance :: 60760272.69, average exp. loss :: 6.10e+11
# episode 69: ending balance :: -18079.87, average exp. loss :: 3.52e+07
# episode 70: ending balance :: -4995.37, average exp. loss :: 2.09e+07
# episode 71: ending balance :: -89773.43, average exp. loss :: 5.33e+08
# episode 72: ending balance :: -2257.31, average exp. loss :: 3.53e+06
# episode 73: ending balance :: -8345.24, average exp. loss :: 1.34e+07
# episode 74: ending balance :: -2227893.46, average exp. loss :: 2.47e+09
# episode 75: ending balance :: -14246.89, average exp. loss :: 1.01e+07
# episode 76: ending balance :: -5705.94, average exp. loss :: 1.04e+07
# episode 77: ending balance :: -6047.03, average exp. loss :: 2.39e+07
# episode 78: ending balance :: -373.39, average exp. loss :: 1.45e+06
# episode 79: ending balance :: -45246.52, average exp. loss :: 8.28e+07
# episode 80: ending balance :: -2911470.61, average exp. loss :: 4.25e+12
# episode 81: ending balance :: 883604.17, average exp. loss :: 1.81e+07
# episode 82: ending balance :: -2509.82, average exp. loss :: 8.34e+06
# episode 83: ending balance :: -1286.71, average exp. loss :: 2.41e+06
# episode 84: ending balance :: -28379.30, average exp. loss :: 3.74e+07
# episode 85: ending balance :: -28452.10, average exp. loss :: 9.50e+07
# episode 86: ending balance :: -11573.03, average exp. loss :: 9.02e+07
# episode 87: ending balance :: -572.46, average exp. loss :: 1.01e+07
# episode 88: ending balance :: -796.32, average exp. loss :: 2.81e+06
# syncing network weights...
# episode 89: ending balance :: 3082861.54, average exp. loss :: 1.14e+09
# episode 90: ending balance :: -43676.26, average exp. loss :: 2.02e+07
# episode 91: ending balance :: 2015271.47, average exp. loss :: 2.16e+08
# episode 92: ending balance :: 840298.61, average exp. loss :: 4.73e+08
# episode 93: ending balance :: -2469.26, average exp. loss :: 4.02e+06
# episode 94: ending balance :: -14.93, average exp. loss :: 1.12e+06
# episode 95: ending balance :: -2871514.93, average exp. loss :: 2.14e+10
# episode 96: ending balance :: -2310.13, average exp. loss :: 6.57e+06
# episode 97: ending balance :: -13812.92, average exp. loss :: 8.84e+06
# episode 98: ending balance :: -1372217.85, average exp. loss :: 2.41e+09
# episode 99: ending balance :: -414853.96, average exp. loss :: 2.46e+08
# episode 100: ending balance :: -35.81, average exp. loss :: 1.14e+07
# episode 101: ending balance :: -2233.99, average exp. loss :: 2.23e+07
# episode 102: ending balance :: -12985.86, average exp. loss :: 1.67e+07
# syncing network weights...
# episode 103: ending balance :: -9840.53, average exp. loss :: 1.66e+07
# episode 104: ending balance :: -749554.67, average exp. loss :: 4.68e+08
# episode 105: ending balance :: -688933.67, average exp. loss :: 2.33e+09
# episode 106: ending balance :: -16274.32, average exp. loss :: 2.35e+08
# episode 107: ending balance :: -21750.54, average exp. loss :: 8.27e+06
# episode 108: ending balance :: -855.43, average exp. loss :: 1.32e+06
# episode 109: ending balance :: 1548533.64, average exp. loss :: 1.83e+08
# episode 110: ending balance :: -68262.82, average exp. loss :: 7.79e+07
# episode 111: ending balance :: 787607.87, average exp. loss :: 8.34e+06
# episode 112: ending balance :: -1233.89, average exp. loss :: 1.98e+05
# episode 113: ending balance :: -199171.54, average exp. loss :: 1.59e+08
# episode 114: ending balance :: -99165.25, average exp. loss :: 1.85e+08
# episode 115: ending balance :: -2206.03, average exp. loss :: 2.86e+07
# episode 116: ending balance :: -1525.03, average exp. loss :: 2.36e+07
# syncing network weights...
# episode 117: ending balance :: -19387068.75, average exp. loss :: 1.31e+11
# episode 118: ending balance :: -1520.60, average exp. loss :: 1.07e+07
# episode 119: ending balance :: -168229.60, average exp. loss :: 1.26e+08
# episode 120: ending balance :: -433.35, average exp. loss :: 1.60e+07
# episode 121: ending balance :: -13318.88, average exp. loss :: 1.11e+08
# episode 122: ending balance :: -17355.02, average exp. loss :: 1.20e+07
# episode 123: ending balance :: -132069.39, average exp. loss :: 1.33e+08
# episode 124: ending balance :: -16778.69, average exp. loss :: 1.44e+08
# episode 125: ending balance :: -1940.64, average exp. loss :: 4.10e+06
# episode 126: ending balance :: -10947.57, average exp. loss :: 5.22e+07
# episode 127: ending balance :: 689415.94, average exp. loss :: 3.83e+07
# episode 128: ending balance :: -310.84, average exp. loss :: 3.55e+06
# episode 129: ending balance :: -3938.46, average exp. loss :: 4.29e+07
# episode 130: ending balance :: -3025.81, average exp. loss :: 3.48e+07
# episode 131: ending balance :: -1530.24, average exp. loss :: 6.36e+06
# episode 132: ending balance :: -448.51, average exp. loss :: 8.34e+05
# episode 133: ending balance :: -3353.30, average exp. loss :: 3.72e+07
# episode 134: ending balance :: 4413737.45, average exp. loss :: 2.23e+09
# episode 135: ending balance :: -1401.27, average exp. loss :: 3.05e+06
# episode 136: ending balance :: -264462.94, average exp. loss :: 3.64e+09
# episode 137: ending balance :: -1492.91, average exp. loss :: 2.28e+07
# episode 138: ending balance :: -1658.34, average exp. loss :: 5.94e+06
# episode 139: ending balance :: -3426.49, average exp. loss :: 2.20e+06
# syncing network weights...
# episode 140: ending balance :: 744885.86, average exp. loss :: 2.14e+07
# episode 141: ending balance :: -65825.10, average exp. loss :: 1.60e+08
# episode 142: ending balance :: 4457249.32, average exp. loss :: 2.15e+09
# episode 143: ending balance :: -122613.78, average exp. loss :: 9.24e+07
# episode 144: ending balance :: -48713.67, average exp. loss :: 7.94e+08
# episode 145: ending balance :: -84.16, average exp. loss :: 7.79e+06
# episode 146: ending balance :: -14295.14, average exp. loss :: 2.01e+07
# episode 147: ending balance :: -108452.05, average exp. loss :: 1.03e+08
# episode 148: ending balance :: -541.05, average exp. loss :: 1.69e+07
# episode 149: ending balance :: 626556.76, average exp. loss :: 3.57e+07
# episode 150: ending balance :: -9499.22, average exp. loss :: 1.26e+07
# episode 151: ending balance :: -6894.41, average exp. loss :: 7.39e+07
# syncing network weights...
# episode 152: ending balance :: -26768.65, average exp. loss :: 2.05e+07
# episode 153: ending balance :: -946601.97, average exp. loss :: 9.23e+08
# episode 154: ending balance :: -3970.92, average exp. loss :: 3.65e+07
# episode 155: ending balance :: -1014.17, average exp. loss :: 2.27e+07
# episode 156: ending balance :: -9897.64, average exp. loss :: 3.13e+07
# episode 157: ending balance :: -24773.77, average exp. loss :: 1.73e+08
# episode 158: ending balance :: -4188.44, average exp. loss :: 4.04e+07
# episode 159: ending balance :: -5221.06, average exp. loss :: 4.71e+07
# episode 160: ending balance :: -6455.60, average exp. loss :: 5.57e+07
# episode 161: ending balance :: -7944.64, average exp. loss :: 6.72e+07
# episode 162: ending balance :: -9775.86, average exp. loss :: 8.29e+07
# episode 163: ending balance :: -27564.28, average exp. loss :: 3.14e+07
# episode 164: ending balance :: -7176.99, average exp. loss :: 2.03e+07
# episode 165: ending balance :: -1409.29, average exp. loss :: 2.32e+07
# episode 166: ending balance :: 1344341.67, average exp. loss :: 2.33e+07
# episode 167: ending balance :: 2059435.26, average exp. loss :: 2.45e+08
# episode 168: ending balance :: -664.25, average exp. loss :: 3.95e+06
# episode 169: ending balance :: 508985.16, average exp. loss :: 1.67e+07
# syncing network weights...
# episode 170: ending balance :: -21565.44, average exp. loss :: 4.61e+06
# episode 171: ending balance :: 730334.56, average exp. loss :: 3.56e+06
# episode 172: ending balance :: -536365.03, average exp. loss :: 6.33e+08
# episode 173: ending balance :: -6095.02, average exp. loss :: 3.86e+07
# episode 174: ending balance :: 1331172.87, average exp. loss :: 8.62e+06
# episode 175: ending balance :: -17627.91, average exp. loss :: 2.86e+07
# episode 176: ending balance :: -45975.56, average exp. loss :: 1.30e+09
# episode 177: ending balance :: -7069.96, average exp. loss :: 7.41e+07
# episode 178: ending balance :: -454.57, average exp. loss :: 2.39e+06
# syncing network weights...
# episode 179: ending balance :: 1943245.80, average exp. loss :: 6.53e+07
# episode 180: ending balance :: -8166.19, average exp. loss :: 3.51e+07
# episode 181: ending balance :: 1832401.35, average exp. loss :: 1.61e+07
# episode 182: ending balance :: -3927.36, average exp. loss :: 5.63e+06
# episode 183: ending balance :: -3842.71, average exp. loss :: 3.74e+07
# episode 184: ending balance :: -17511.03, average exp. loss :: 2.28e+07
# episode 185: ending balance :: 1223383.72, average exp. loss :: 6.60e+06
# syncing network weights...
# episode 186: ending balance :: 1228142.07, average exp. loss :: 2.80e+06
# episode 187: ending balance :: -1926.44, average exp. loss :: 2.80e+06
# episode 188: ending balance :: -381.72, average exp. loss :: 1.97e+07
# episode 189: ending balance :: -5178.89, average exp. loss :: 7.89e+06
# episode 190: ending balance :: 944121.22, average exp. loss :: 2.70e+06
# episode 191: ending balance :: -8.82, average exp. loss :: 2.95e+06
# episode 192: ending balance :: -545450.93, average exp. loss :: 5.24e+08
# episode 193: ending balance :: 1498739.44, average exp. loss :: 1.66e+07
# episode 194: ending balance :: -8777.62, average exp. loss :: 1.06e+07
# episode 195: ending balance :: -43844.32, average exp. loss :: 1.20e+09
# episode 196: ending balance :: -4119336.19, average exp. loss :: 2.91e+10
# syncing network weights...
# episode 197: ending balance :: 1491017.73, average exp. loss :: 5.12e+07
# episode 198: ending balance :: -714.54, average exp. loss :: 9.29e+06
# episode 199: ending balance :: -16554.19, average exp. loss :: 9.09e+07
# episode 200: ending balance :: -84352.08, average exp. loss :: 1.37e+09
# episode 201: ending balance :: -5732.17, average exp. loss :: 1.59e+07
# episode 202: ending balance :: -55.31, average exp. loss :: 2.92e+06
# episode 203: ending balance :: -73701.00, average exp. loss :: 1.69e+09
# episode 204: ending balance :: -146237.49, average exp. loss :: 5.98e+09
# episode 205: ending balance :: -4043.71, average exp. loss :: 6.35e+06
# episode 206: ending balance :: -18513.64, average exp. loss :: 1.77e+08
# episode 207: ending balance :: 3651280.95, average exp. loss :: 3.36e+08
# episode 208: ending balance :: -1483.32, average exp. loss :: 1.16e+07
# episode 209: ending balance :: -31351.02, average exp. loss :: 4.45e+07
# episode 210: ending balance :: 1431704.49, average exp. loss :: 3.48e+08
# episode 211: ending balance :: -498.06, average exp. loss :: 3.91e+06
# episode 212: ending balance :: -124109.50, average exp. loss :: 2.83e+09
# episode 213: ending balance :: -10717.73, average exp. loss :: 5.01e+07
# episode 214: ending balance :: -29741.83, average exp. loss :: 2.49e+08
# episode 215: ending balance :: -12472.23, average exp. loss :: 4.28e+07
# episode 216: ending balance :: -408.93, average exp. loss :: 2.20e+07
# episode 217: ending balance :: -863.63, average exp. loss :: 2.41e+07
# episode 218: ending balance :: -1784.04, average exp. loss :: 2.62e+06
# episode 219: ending balance :: 964494.52, average exp. loss :: 1.12e+07
# episode 220: ending balance :: -1186.44, average exp. loss :: 1.76e+06
# syncing network weights...
# episode 221: ending balance :: 650131.75, average exp. loss :: 1.37e+06
# episode 222: ending balance :: 719912.77, average exp. loss :: 2.32e+06
# episode 223: ending balance :: 2067440.49, average exp. loss :: 4.04e+08
# episode 224: ending balance :: -3271.71, average exp. loss :: 3.42e+06
# episode 225: ending balance :: -2247.40, average exp. loss :: 4.53e+06
# syncing network weights...
# episode 226: ending balance :: 1081819.22, average exp. loss :: 7.02e+06
# episode 227: ending balance :: 970136.12, average exp. loss :: 1.50e+07
# episode 228: ending balance :: -8683.06, average exp. loss :: 7.19e+07
# episode 229: ending balance :: 1168363.43, average exp. loss :: 5.73e+06
# episode 230: ending balance :: -1428.61, average exp. loss :: 4.97e+06
# episode 231: ending balance :: -2724.49, average exp. loss :: 3.31e+07
# episode 232: ending balance :: -3542.00, average exp. loss :: 3.78e+07
# episode 233: ending balance :: -2082.06, average exp. loss :: 2.99e+06
# episode 234: ending balance :: -5026.23, average exp. loss :: 4.44e+07
# episode 235: ending balance :: -4155.53, average exp. loss :: 3.88e+07
# syncing network weights...
# episode 236: ending balance :: -295539.41, average exp. loss :: 5.12e+08
# episode 237: ending balance :: -21416.41, average exp. loss :: 2.19e+08
# episode 238: ending balance :: -6302.81, average exp. loss :: 1.11e+07
# episode 239: ending balance :: 1054423.00, average exp. loss :: 5.09e+06
# episode 240: ending balance :: -426.65, average exp. loss :: 8.49e+06
# episode 241: ending balance :: -7115.76, average exp. loss :: 7.53e+06
# episode 242: ending balance :: 778782.15, average exp. loss :: 1.05e+06
# episode 243: ending balance :: -16447.61, average exp. loss :: 8.83e+07
# episode 244: ending balance :: -11512.71, average exp. loss :: 7.05e+07
# episode 245: ending balance :: -2091.87, average exp. loss :: 2.91e+06
# episode 246: ending balance :: -101997.81, average exp. loss :: 2.54e+08
# episode 247: ending balance :: -108004.73, average exp. loss :: 5.28e+07
# episode 248: ending balance :: 488411.56, average exp. loss :: 5.70e+06
# syncing network weights...
# episode 249: ending balance :: -67653.24, average exp. loss :: 4.59e+07
# episode 250: ending balance :: -58292.00, average exp. loss :: 2.15e+07
# episode 251: ending balance :: -9755.51, average exp. loss :: 1.37e+07
# episode 252: ending balance :: 502219.07, average exp. loss :: 5.15e+06
# episode 253: ending balance :: -99.27, average exp. loss :: 3.45e+06
# episode 254: ending balance :: -729.29, average exp. loss :: 8.74e+06
# episode 255: ending balance :: -705.89, average exp. loss :: 8.69e+06
# episode 256: ending balance :: -682.50, average exp. loss :: 8.64e+06
# episode 257: ending balance :: -659.27, average exp. loss :: 8.59e+06
# episode 258: ending balance :: -636.00, average exp. loss :: 8.54e+06
# episode 259: ending balance :: -613.37, average exp. loss :: 8.49e+06
# episode 260: ending balance :: 333578.65, average exp. loss :: 3.65e+05
# episode 261: ending balance :: -3870.79, average exp. loss :: 3.48e+07
# episode 262: ending balance :: 599536.25, average exp. loss :: 6.78e+06
# episode 263: ending balance :: -183587.69, average exp. loss :: 5.66e+09
# syncing network weights...
# episode 264: ending balance :: 386321.94, average exp. loss :: 2.81e+05
# episode 265: ending balance :: 331933.77, average exp. loss :: 1.07e+06
# episode 266: ending balance :: -2269.41, average exp. loss :: 1.32e+06
# episode 267: ending balance :: 290070.87, average exp. loss :: 4.55e+05
# episode 268: ending balance :: -36638.46, average exp. loss :: 3.83e+07
# syncing network weights...
# episode 269: ending balance :: 277439.66, average exp. loss :: 4.03e+05
# episode 270: ending balance :: -396651.48, average exp. loss :: 8.10e+08
# episode 271: ending balance :: -14187.64, average exp. loss :: 1.87e+08
# episode 272: ending balance :: -90098.22, average exp. loss :: 2.87e+08
# episode 273: ending balance :: 317380.27, average exp. loss :: 5.80e+05
# episode 274: ending balance :: -16365.06, average exp. loss :: 5.23e+06
# episode 275: ending balance :: 471123.54, average exp. loss :: 5.02e+06
# syncing network weights...
# episode 276: ending balance :: 336750.72, average exp. loss :: 2.54e+05
# episode 277: ending balance :: 321599.51, average exp. loss :: 2.96e+05
# episode 278: ending balance :: 287863.10, average exp. loss :: 2.97e+05
# syncing network weights...
# episode 279: ending balance :: 274032.64, average exp. loss :: 3.40e+05
# episode 280: ending balance :: 293824.32, average exp. loss :: 2.10e+05
# episode 281: ending balance :: 279429.49, average exp. loss :: 2.32e+05
# episode 282: ending balance :: 278807.93, average exp. loss :: 2.72e+05
# episode 283: ending balance :: -378.86, average exp. loss :: 1.09e+06
# syncing network weights...
# episode 284: ending balance :: 376468.77, average exp. loss :: 6.36e+06
# episode 285: ending balance :: -15259.07, average exp. loss :: 1.01e+07
# episode 286: ending balance :: -789.16, average exp. loss :: 3.94e+05
# episode 287: ending balance :: 341057.32, average exp. loss :: 2.14e+05
# episode 288: ending balance :: 356771.21, average exp. loss :: 1.63e+06
# episode 289: ending balance :: -863.72, average exp. loss :: 3.72e+06
# syncing network weights...
# episode 290: ending balance :: 338684.16, average exp. loss :: 1.96e+05
# episode 291: ending balance :: 375815.24, average exp. loss :: 1.26e+06
# episode 292: ending balance :: 293621.31, average exp. loss :: 1.50e+05
# syncing network weights...
# episode 293: ending balance :: 306407.87, average exp. loss :: 1.05e+07
# episode 294: ending balance :: 356369.62, average exp. loss :: 4.79e+06
# episode 295: ending balance :: 359155.60, average exp. loss :: 3.18e+05
# episode 296: ending balance :: 393180.86, average exp. loss :: 4.23e+05
# episode 297: ending balance :: -437777.84, average exp. loss :: 6.21e+08
# episode 298: ending balance :: -652.64, average exp. loss :: 8.98e+05
# episode 299: ending balance :: -8990.86, average exp. loss :: 3.40e+06
# episode 300: ending balance :: -2164.81, average exp. loss :: 3.12e+06
# syncing network weights...
# episode 301: ending balance :: 449338.10, average exp. loss :: 2.19e+05
# episode 302: ending balance :: -1255237.52, average exp. loss :: 2.25e+10
# episode 303: ending balance :: -267.33, average exp. loss :: 1.45e+07
# episode 304: ending balance :: 911448.46, average exp. loss :: 2.89e+07
# episode 305: ending balance :: 368786.05, average exp. loss :: 3.29e+06
# syncing network weights...
# episode 306: ending balance :: 438437.04, average exp. loss :: 2.32e+05
# episode 307: ending balance :: -3021.98, average exp. loss :: 4.28e+06
# episode 308: ending balance :: 500011.30, average exp. loss :: 3.08e+05
# episode 309: ending balance :: 576161.34, average exp. loss :: 9.43e+06
# syncing network weights...
# episode 310: ending balance :: 348773.01, average exp. loss :: 5.97e+05
# episode 311: ending balance :: -32727.35, average exp. loss :: 4.38e+07
# episode 312: ending balance :: -3817.92, average exp. loss :: 5.33e+06
# episode 313: ending balance :: 445187.47, average exp. loss :: 2.17e+05
# episode 314: ending balance :: 367088.88, average exp. loss :: 4.55e+05
# episode 315: ending balance :: 527239.52, average exp. loss :: 3.98e+06
# syncing network weights...
# episode 316: ending balance :: 450634.04, average exp. loss :: 2.28e+05
# episode 317: ending balance :: -17296.58, average exp. loss :: 1.31e+07
# episode 318: ending balance :: -2963.57, average exp. loss :: 3.24e+07
# episode 319: ending balance :: -61245.61, average exp. loss :: 4.52e+08
# episode 320: ending balance :: 401461.22, average exp. loss :: 1.70e+06
# episode 321: ending balance :: -2710.72, average exp. loss :: 4.95e+06
# episode 322: ending balance :: 481031.17, average exp. loss :: 3.91e+05
# syncing network weights...
# episode 323: ending balance :: 336484.58, average exp. loss :: 1.81e+06
# episode 324: ending balance :: 321254.28, average exp. loss :: 3.81e+06
# episode 325: ending balance :: 505890.01, average exp. loss :: 2.96e+05
# episode 326: ending balance :: -561.67, average exp. loss :: 7.41e+06
# episode 327: ending balance :: -14859.29, average exp. loss :: 7.83e+07
# episode 328: ending balance :: -5199.81, average exp. loss :: 3.68e+06
# syncing network weights...
# episode 329: ending balance :: 521262.87, average exp. loss :: 4.46e+05
# episode 330: ending balance :: 511207.79, average exp. loss :: 6.42e+05
# episode 331: ending balance :: -6084.19, average exp. loss :: 4.62e+06
# episode 332: ending balance :: -11782.71, average exp. loss :: 9.96e+07
# episode 333: ending balance :: -174909.53, average exp. loss :: 1.21e+08
# episode 334: ending balance :: 622715.38, average exp. loss :: 1.15e+07
# episode 335: ending balance :: 480278.33, average exp. loss :: 1.67e+06
# syncing network weights...
# episode 336: ending balance :: 461738.03, average exp. loss :: 2.28e+05
# episode 337: ending balance :: 309437.92, average exp. loss :: 1.00e+06
# episode 338: ending balance :: 473811.00, average exp. loss :: 3.27e+05
# syncing network weights...
# episode 339: ending balance :: 359423.85, average exp. loss :: 1.16e+06
# episode 340: ending balance :: 531183.89, average exp. loss :: 2.90e+05
# episode 341: ending balance :: -372411.04, average exp. loss :: 1.35e+08
# episode 342: ending balance :: -87.14, average exp. loss :: 3.75e+05
# syncing network weights...
# episode 343: ending balance :: 3576041.36, average exp. loss :: 1.87e+09
# episode 344: ending balance :: 614072.09, average exp. loss :: 1.33e+06
# episode 345: ending balance :: 411481.36, average exp. loss :: 3.60e+06
# episode 346: ending balance :: -2816.12, average exp. loss :: 8.64e+06
# episode 347: ending balance :: -2048.52, average exp. loss :: 2.50e+07
# episode 348: ending balance :: 421661.96, average exp. loss :: 3.85e+06
# syncing network weights...
# episode 349: ending balance :: 631906.31, average exp. loss :: 4.19e+05
# episode 350: ending balance :: 1187376.39, average exp. loss :: 1.01e+08
# episode 351: ending balance :: 645425.59, average exp. loss :: 8.34e+05
# syncing network weights...
# episode 352: ending balance :: 651716.32, average exp. loss :: 6.12e+05
# episode 353: ending balance :: 662024.81, average exp. loss :: 4.46e+06
# episode 354: ending balance :: 776054.69, average exp. loss :: 6.13e+05
# syncing network weights...
# episode 355: ending balance :: 824077.33, average exp. loss :: 8.10e+05
# episode 356: ending balance :: 873961.54, average exp. loss :: 1.26e+06
# episode 357: ending balance :: 879865.82, average exp. loss :: 5.66e+06
# episode 358: ending balance :: -8982.03, average exp. loss :: 1.07e+07
# episode 359: ending balance :: -87777.19, average exp. loss :: 1.61e+08
# episode 360: ending balance :: -74.76, average exp. loss :: 1.15e+07
# episode 361: ending balance :: -558.45, average exp. loss :: 1.48e+07
# episode 362: ending balance :: -24793.36, average exp. loss :: 2.85e+08
# episode 363: ending balance :: -3451.57, average exp. loss :: 1.31e+07
# episode 364: ending balance :: -4561.02, average exp. loss :: 7.93e+06
# episode 365: ending balance :: -1581.38, average exp. loss :: 2.13e+07
# episode 366: ending balance :: -255.71, average exp. loss :: 1.15e+07
# episode 367: ending balance :: -3112.37, average exp. loss :: 4.11e+07
# episode 368: ending balance :: -15099.32, average exp. loss :: 1.46e+08
# episode 369: ending balance :: -3122.24, average exp. loss :: 1.26e+07
# episode 370: ending balance :: -14706.47, average exp. loss :: 1.79e+07
# episode 371: ending balance :: -23718.93, average exp. loss :: 1.29e+08
# episode 372: ending balance :: 1001428.68, average exp. loss :: 1.08e+06
# syncing network weights...
# episode 373: ending balance :: 800458.93, average exp. loss :: 9.39e+05
# episode 374: ending balance :: 1278736.12, average exp. loss :: 5.10e+07
# episode 375: ending balance :: 739957.66, average exp. loss :: 7.19e+05
# syncing network weights...
# episode 376: ending balance :: 719426.31, average exp. loss :: 6.03e+05
# episode 377: ending balance :: -2405.78, average exp. loss :: 3.30e+07
# episode 378: ending balance :: -1832.54, average exp. loss :: 2.98e+07
# episode 379: ending balance :: -1321.06, average exp. loss :: 2.71e+07
# episode 380: ending balance :: -862.10, average exp. loss :: 2.48e+07
# episode 381: ending balance :: 3148622.18, average exp. loss :: 1.28e+09
# episode 382: ending balance :: -83.59, average exp. loss :: 1.15e+07
# episode 383: ending balance :: -611.90, average exp. loss :: 1.21e+07
# episode 384: ending balance :: -11900.85, average exp. loss :: 1.99e+07
# episode 385: ending balance :: -4599782.39, average exp. loss :: 1.43e+11
# episode 386: ending balance :: 783680.04, average exp. loss :: 6.47e+05
# episode 387: ending balance :: -2761.69, average exp. loss :: 3.58e+07
# syncing network weights...
# episode 388: ending balance :: 766731.87, average exp. loss :: 1.70e+06
# episode 389: ending balance :: -8463.57, average exp. loss :: 7.85e+07
# episode 390: ending balance :: -6832.50, average exp. loss :: 6.47e+07
# episode 391: ending balance :: -5498.31, average exp. loss :: 5.45e+07
# episode 392: ending balance :: -4387.17, average exp. loss :: 4.66e+07
# episode 393: ending balance :: -3447.59, average exp. loss :: 4.05e+07
# episode 394: ending balance :: -7195.52, average exp. loss :: 2.40e+07
# episode 395: ending balance :: -691.38, average exp. loss :: 3.50e+06
# episode 396: ending balance :: 795271.92, average exp. loss :: 8.31e+05
# episode 397: ending balance :: -27055.06, average exp. loss :: 3.32e+08
# episode 398: ending balance :: -13725.77, average exp. loss :: 5.14e+07
# episode 399: ending balance :: 761339.76, average exp. loss :: 9.94e+05
# episode 400: ending balance :: -476.71, average exp. loss :: 4.48e+06
# episode 401: ending balance :: -113.87, average exp. loss :: 1.13e+07
# episode 402: ending balance :: -36565.51, average exp. loss :: 2.61e+08
# syncing network weights...
# episode 403: ending balance :: 829394.49, average exp. loss :: 8.05e+05
# episode 404: ending balance :: -14063.56, average exp. loss :: 1.38e+08
# episode 405: ending balance :: -11155.27, average exp. loss :: 1.06e+08
# episode 406: ending balance :: -8924.12, average exp. loss :: 8.40e+07
# episode 407: ending balance :: -1591.64, average exp. loss :: 5.07e+06
# episode 408: ending balance :: -1188.13, average exp. loss :: 9.36e+06
# episode 409: ending balance :: -34.18, average exp. loss :: 7.45e+06
# episode 410: ending balance :: -1090.06, average exp. loss :: 3.78e+06
# episode 411: ending balance :: 315367.07, average exp. loss :: 4.49e+07
# episode 412: ending balance :: -101.37, average exp. loss :: 7.70e+06
# episode 413: ending balance :: -938.87, average exp. loss :: 4.75e+06
# episode 414: ending balance :: 937807.48, average exp. loss :: 1.39e+06
# episode 415: ending balance :: -4162.34, average exp. loss :: 1.62e+07
# episode 416: ending balance :: 913221.11, average exp. loss :: 9.78e+05
# episode 417: ending balance :: -14500.52, average exp. loss :: 1.46e+08
# syncing network weights...
# episode 418: ending balance :: 974897.80, average exp. loss :: 1.40e+06
# episode 419: ending balance :: -892.64, average exp. loss :: 3.93e+06
# episode 420: ending balance :: -11479.35, average exp. loss :: 1.04e+07
# episode 421: ending balance :: 959869.23, average exp. loss :: 1.05e+06
# episode 422: ending balance :: -46966.49, average exp. loss :: 8.06e+08
# episode 423: ending balance :: -32304.33, average exp. loss :: 4.44e+08
# episode 424: ending balance :: 1048985.88, average exp. loss :: 4.87e+06
# episode 425: ending balance :: -71482.17, average exp. loss :: 1.65e+09
# episode 426: ending balance :: -43914.67, average exp. loss :: 7.22e+08
# episode 427: ending balance :: -30465.09, average exp. loss :: 4.06e+08
# episode 428: ending balance :: -22502.65, average exp. loss :: 2.62e+08
# episode 429: ending balance :: -141.99, average exp. loss :: 3.72e+06
# episode 430: ending balance :: -5444.81, average exp. loss :: 1.94e+07
# episode 431: ending balance :: -17686.68, average exp. loss :: 7.97e+07
# episode 432: ending balance :: -7284.19, average exp. loss :: 2.63e+07
# syncing network weights...
# episode 433: ending balance :: 908390.76, average exp. loss :: 1.02e+06
# episode 434: ending balance :: 1092757.70, average exp. loss :: 9.40e+06
# episode 435: ending balance :: -495.60, average exp. loss :: 4.56e+06
# episode 436: ending balance :: -14983.50, average exp. loss :: 1.51e+08
# episode 437: ending balance :: -268.85, average exp. loss :: 3.31e+06
# episode 438: ending balance :: -3345.24, average exp. loss :: 1.41e+07
# episode 439: ending balance :: -1218.72, average exp. loss :: 9.72e+06
# episode 440: ending balance :: -255.09, average exp. loss :: 8.05e+06
# episode 441: ending balance :: -1976.20, average exp. loss :: 4.36e+06
# episode 442: ending balance :: -1820.49, average exp. loss :: 4.26e+06
# episode 443: ending balance :: -1709.48, average exp. loss :: 4.19e+06
# episode 444: ending balance :: 888861.56, average exp. loss :: 8.38e+05
# episode 445: ending balance :: -10588.06, average exp. loss :: 3.95e+07
# episode 446: ending balance :: -3261.86, average exp. loss :: 1.42e+07
# episode 447: ending balance :: -1400.27, average exp. loss :: 1.03e+07
# syncing network weights...
# episode 448: ending balance :: 886471.82, average exp. loss :: 1.03e+06
# episode 449: ending balance :: -23814.09, average exp. loss :: 2.90e+08
# episode 450: ending balance :: -32496.84, average exp. loss :: 4.56e+08
# episode 451: ending balance :: -634.03, average exp. loss :: 4.92e+06
# episode 452: ending balance :: -4351.55, average exp. loss :: 5.05e+07
# episode 453: ending balance :: -73.54, average exp. loss :: 3.29e+06
# episode 454: ending balance :: -2025.88, average exp. loss :: 1.18e+07
# episode 455: ending balance :: 962157.67, average exp. loss :: 1.03e+06
# episode 456: ending balance :: -40832.46, average exp. loss :: 6.48e+08
# episode 457: ending balance :: -4090.43, average exp. loss :: 1.69e+07
# episode 458: ending balance :: -32802.40, average exp. loss :: 2.25e+08
# episode 459: ending balance :: -18433.10, average exp. loss :: 8.93e+07
# episode 460: ending balance :: -5875.34, average exp. loss :: 2.27e+07
# episode 461: ending balance :: -3002.70, average exp. loss :: 1.45e+07
# episode 462: ending balance :: -1494.81, average exp. loss :: 1.11e+07
# episode 463: ending balance :: -2387.86, average exp. loss :: 1.95e+06
# episode 464: ending balance :: -6601.41, average exp. loss :: 7.81e+07
# episode 465: ending balance :: -4905.03, average exp. loss :: 5.74e+07
# episode 466: ending balance :: -8049.60, average exp. loss :: 3.13e+07
# episode 467: ending balance :: 495448.14, average exp. loss :: 3.29e+07
# episode 468: ending balance :: -22387.62, average exp. loss :: 1.36e+08
# episode 469: ending balance :: -67171.76, average exp. loss :: 1.51e+09
# episode 470: ending balance :: -981.18, average exp. loss :: 1.32e+07
# episode 471: ending balance :: -2127.92, average exp. loss :: 4.99e+06
# episode 472: ending balance :: 1101150.93, average exp. loss :: 2.49e+06
# syncing network weights...
# episode 473: ending balance :: 451826.86, average exp. loss :: 4.76e+07
# episode 474: ending balance :: -248366.96, average exp. loss :: 2.68e+08
# episode 475: ending balance :: 1169679.25, average exp. loss :: 1.98e+06
# syncing network weights...
# episode 476: ending balance :: 1519200.74, average exp. loss :: 4.83e+07
# episode 477: ending balance :: 1193647.55, average exp. loss :: 1.80e+06
# episode 478: ending balance :: 1633258.58, average exp. loss :: 7.02e+07
# syncing network weights...
# episode 479: ending balance :: 1272636.83, average exp. loss :: 5.08e+06
# episode 480: ending balance :: 1450432.65, average exp. loss :: 6.35e+06
# episode 481: ending balance :: 1303221.88, average exp. loss :: 3.43e+06
# episode 482: ending balance :: 1405336.27, average exp. loss :: 6.62e+06
# episode 483: ending balance :: -87648.12, average exp. loss :: 4.64e+08
# syncing network weights...
# episode 484: ending balance :: 1108316.76, average exp. loss :: 1.47e+06
# episode 485: ending balance :: 1119609.64, average exp. loss :: 2.00e+06
# episode 486: ending balance :: 1024287.60, average exp. loss :: 1.15e+06
# episode 487: ending balance :: -1418.81, average exp. loss :: 9.53e+06
# syncing network weights...
# episode 488: ending balance :: 974288.22, average exp. loss :: 1.02e+06
# episode 489: ending balance :: 1058467.79, average exp. loss :: 1.31e+06
# episode 490: ending balance :: 1063576.45, average exp. loss :: 1.48e+06
# syncing network weights...
# episode 491: ending balance :: 1068804.99, average exp. loss :: 1.67e+06
# episode 492: ending balance :: 1202181.93, average exp. loss :: 3.68e+06
# episode 493: ending balance :: 1152728.22, average exp. loss :: 1.58e+06
# episode 494: ending balance :: 1163987.46, average exp. loss :: 1.55e+06
# syncing network weights...
# episode 495: ending balance :: 1147379.32, average exp. loss :: 1.53e+06
# episode 496: ending balance :: 1177866.34, average exp. loss :: 1.74e+06
# episode 497: ending balance :: 1209269.70, average exp. loss :: 2.00e+06
# syncing network weights...
# episode 498: ending balance :: 1229035.00, average exp. loss :: 2.34e+06
# episode 499: ending balance :: 1218935.60, average exp. loss :: 2.63e+06
# episode 500: ending balance :: 1256351.82, average exp. loss :: 3.36e+06
# syncing network weights...
# episode 501: ending balance :: 1270002.91, average exp. loss :: 3.48e+06
# episode 502: ending balance :: -1941.54, average exp. loss :: 1.06e+07
# episode 503: ending balance :: 1097393.72, average exp. loss :: 1.32e+06
# episode 504: ending balance :: 1103380.62, average exp. loss :: 1.43e+06
# episode 505: ending balance :: 1109286.86, average exp. loss :: 1.34e+06
# episode 506: ending balance :: -181539.83, average exp. loss :: 6.07e+09
# episode 507: ending balance :: -9986.80, average exp. loss :: 7.17e+07
# episode 508: ending balance :: -1398.40, average exp. loss :: 2.96e+07
# episode 509: ending balance :: -5075.58, average exp. loss :: 4.14e+07
# episode 510: ending balance :: -71759.57, average exp. loss :: 1.03e+09
# episode 511: ending balance :: -653.63, average exp. loss :: 2.62e+07
# episode 512: ending balance :: -6090.66, average exp. loss :: 2.02e+07
# episode 513: ending balance :: -4782.39, average exp. loss :: 2.08e+07
# episode 514: ending balance :: -1581.18, average exp. loss :: 6.72e+07
# episode 515: ending balance :: -3639.12, average exp. loss :: 8.42e+07
# episode 516: ending balance :: -6466.18, average exp. loss :: 1.11e+08
# episode 517: ending balance :: -10577.89, average exp. loss :: 1.57e+08
# episode 518: ending balance :: -17092.32, average exp. loss :: 2.47e+08
# episode 519: ending balance :: -28927.44, average exp. loss :: 4.64e+08
# episode 520: ending balance :: -57005.69, average exp. loss :: 1.26e+09
# episode 521: ending balance :: -206350.87, average exp. loss :: 1.21e+10
# episode 522: ending balance :: -176514.12, average exp. loss :: 9.06e+09
# episode 523: ending balance :: -56661.93, average exp. loss :: 1.26e+09
# episode 524: ending balance :: -25675.91, average exp. loss :: 4.03e+08
# episode 525: ending balance :: -16801.87, average exp. loss :: 2.49e+08
# episode 526: ending balance :: -9081.20, average exp. loss :: 1.46e+08
# episode 527: ending balance :: -4990.71, average exp. loss :: 1.03e+08
# episode 528: ending balance :: -1659.88, average exp. loss :: 7.35e+07
# episode 529: ending balance :: -158.31, average exp. loss :: 3.77e+07
# episode 530: ending balance :: -4254.87, average exp. loss :: 1.60e+07
# episode 531: ending balance :: -2905.33, average exp. loss :: 1.44e+07
# episode 532: ending balance :: -16519.48, average exp. loss :: 2.28e+07
# episode 533: ending balance :: -445.04, average exp. loss :: 1.05e+08
# episode 534: ending balance :: -7946.55, average exp. loss :: 5.15e+07
# episode 535: ending balance :: -656.26, average exp. loss :: 4.20e+06
# syncing network weights...
# episode 536: ending balance :: 1302720.24, average exp. loss :: 3.40e+07
# episode 537: ending balance :: 1003328.47, average exp. loss :: 1.09e+06
# episode 538: ending balance :: 1004749.91, average exp. loss :: 1.07e+06
# syncing network weights...
# episode 539: ending balance :: 1080396.98, average exp. loss :: 2.58e+06
# episode 540: ending balance :: 1011869.64, average exp. loss :: 1.24e+06
# episode 541: ending balance :: -9.16, average exp. loss :: 1.83e+07
# episode 542: ending balance :: -9244.62, average exp. loss :: 1.44e+08
# episode 543: ending balance :: -12953.33, average exp. loss :: 1.92e+08
# episode 544: ending balance :: -18248.52, average exp. loss :: 2.72e+08
# episode 545: ending balance :: -26396.17, average exp. loss :: 4.22e+08
# episode 546: ending balance :: -40508.63, average exp. loss :: 7.61e+08
# episode 547: ending balance :: -70619.17, average exp. loss :: 1.82e+09
# episode 548: ending balance :: -178684.06, average exp. loss :: 9.33e+09
# episode 549: ending balance :: -650420.34, average exp. loss :: 1.11e+11
# episode 550: ending balance :: -108234.17, average exp. loss :: 3.79e+09
# episode 551: ending balance :: -50212.84, average exp. loss :: 1.07e+09
# episode 552: ending balance :: -27840.74, average exp. loss :: 4.75e+08
# episode 553: ending balance :: -16914.28, average exp. loss :: 2.75e+08
# episode 554: ending balance :: -11046.44, average exp. loss :: 1.92e+08
# episode 555: ending balance :: -7175.97, average exp. loss :: 1.48e+08
# episode 556: ending balance :: -3788.83, average exp. loss :: 1.15e+08
# episode 557: ending balance :: -1491.85, average exp. loss :: 9.67e+07
# episode 558: ending balance :: -11076.29, average exp. loss :: 4.05e+07
# episode 559: ending balance :: -447.32, average exp. loss :: 9.37e+07
# episode 560: ending balance :: -73409.06, average exp. loss :: 5.37e+08
# episode 561: ending balance :: -16343.41, average exp. loss :: 2.58e+07
# episode 562: ending balance :: 1020147.62, average exp. loss :: 1.73e+06
# syncing network weights...
# episode 563: ending balance :: 971870.11, average exp. loss :: 9.75e+05
# episode 564: ending balance :: 1070015.58, average exp. loss :: 2.78e+06
# episode 565: ending balance :: 1049619.10, average exp. loss :: 1.74e+06
# episode 566: ending balance :: -17485.35, average exp. loss :: 3.41e+07
# episode 567: ending balance :: 2059993.39, average exp. loss :: 2.87e+08
# episode 568: ending balance :: -12058.00, average exp. loss :: 1.24e+08
# syncing network weights...
# episode 569: ending balance :: 1222273.23, average exp. loss :: 8.79e+06
# episode 570: ending balance :: 1052651.13, average exp. loss :: 2.75e+06
# episode 571: ending balance :: 995099.67, average exp. loss :: 1.36e+06
# syncing network weights...
# episode 572: ending balance :: 968200.56, average exp. loss :: 9.60e+05
# episode 573: ending balance :: -7225.66, average exp. loss :: 1.81e+07
# episode 574: ending balance :: 1008871.19, average exp. loss :: 3.35e+06
# episode 575: ending balance :: 1813699.43, average exp. loss :: 2.26e+08
# syncing network weights...
# episode 576: ending balance :: 930370.43, average exp. loss :: 9.44e+05
# episode 577: ending balance :: -12472.99, average exp. loss :: 2.15e+07
# episode 578: ending balance :: 959028.55, average exp. loss :: 1.38e+06
# episode 579: ending balance :: -53.67, average exp. loss :: 4.13e+07
# episode 580: ending balance :: -5032.35, average exp. loss :: 3.04e+07
# episode 581: ending balance :: -8395.27, average exp. loss :: 9.07e+06
# episode 582: ending balance :: -7151.46, average exp. loss :: 1.17e+08
# episode 583: ending balance :: -2810.55, average exp. loss :: 2.42e+07
# episode 584: ending balance :: 936295.37, average exp. loss :: 9.57e+05
# episode 585: ending balance :: -949.48, average exp. loss :: 7.71e+07
# episode 586: ending balance :: -6052.88, average exp. loss :: 3.58e+07
# episode 587: ending balance :: -2716.44, average exp. loss :: 4.83e+06
# episode 588: ending balance :: -1304.06, average exp. loss :: 5.44e+07
# episode 589: ending balance :: -20086.64, average exp. loss :: 5.85e+07
# episode 590: ending balance :: -1097.36, average exp. loss :: 4.22e+06
# episode 591: ending balance :: -18506.38, average exp. loss :: 5.58e+07
# episode 592: ending balance :: -124.89, average exp. loss :: 4.51e+06
# episode 593: ending balance :: -2118.56, average exp. loss :: 2.55e+07
# episode 594: ending balance :: -29154.67, average exp. loss :: 2.34e+08
# episode 595: ending balance :: 876677.36, average exp. loss :: 8.82e+05
# syncing network weights...
# episode 596: ending balance :: 887517.02, average exp. loss :: 9.51e+05
# episode 597: ending balance :: -30363.43, average exp. loss :: 9.85e+07
# episode 598: ending balance :: -131.89, average exp. loss :: 3.29e+06
# episode 599: ending balance :: 830032.25, average exp. loss :: 6.82e+05
# episode 600: ending balance :: 5627830.92, average exp. loss :: 4.73e+09
# episode 601: ending balance :: -3825.52, average exp. loss :: 8.62e+06
# syncing network weights...
# episode 602: ending balance :: 803123.28, average exp. loss :: 6.85e+05
# episode 603: ending balance :: -578.18, average exp. loss :: 6.80e+06
# episode 604: ending balance :: 1817839.06, average exp. loss :: 2.79e+08
# episode 605: ending balance :: 806920.54, average exp. loss :: 7.90e+05
# episode 606: ending balance :: -6895.04, average exp. loss :: 9.96e+06
# episode 607: ending balance :: -1223.74, average exp. loss :: 3.60e+06
# syncing network weights...
# episode 608: ending balance :: 784114.41, average exp. loss :: 7.19e+05
# episode 609: ending balance :: -80932.88, average exp. loss :: 9.86e+08
# episode 610: ending balance :: 808571.41, average exp. loss :: 6.86e+05
# episode 611: ending balance :: 896873.58, average exp. loss :: 3.09e+06
# episode 612: ending balance :: 820507.60, average exp. loss :: 6.83e+05
# episode 613: ending balance :: -3759.57, average exp. loss :: 6.12e+07
# episode 614: ending balance :: -2857.77, average exp. loss :: 1.61e+07
# episode 615: ending balance :: -3341.46, average exp. loss :: 5.16e+06
# episode 616: ending balance :: -87331.49, average exp. loss :: 2.63e+09
# episode 617: ending balance :: -816.72, average exp. loss :: 4.76e+06
# episode 618: ending balance :: -3131.50, average exp. loss :: 3.21e+07
# syncing network weights...
# episode 619: ending balance :: 898596.10, average exp. loss :: 9.44e+06
# episode 620: ending balance :: -1158.77, average exp. loss :: 5.42e+06
# episode 621: ending balance :: -2608.49, average exp. loss :: 5.34e+06
# episode 622: ending balance :: -510.41, average exp. loss :: 3.06e+06
# episode 623: ending balance :: 783495.76, average exp. loss :: 8.94e+05
# episode 624: ending balance :: 747133.36, average exp. loss :: 5.50e+05
# syncing network weights...
# episode 625: ending balance :: 799099.26, average exp. loss :: 1.30e+06
# episode 626: ending balance :: -2351.12, average exp. loss :: 4.39e+07
# episode 627: ending balance :: -2769.58, average exp. loss :: 1.25e+07
# episode 628: ending balance :: -3453.06, average exp. loss :: 5.24e+06
# episode 629: ending balance :: 801694.75, average exp. loss :: 1.52e+06
# episode 630: ending balance :: -1631.74, average exp. loss :: 6.98e+07
# episode 631: ending balance :: -276154.78, average exp. loss :: 3.90e+09
# episode 632: ending balance :: -14042.01, average exp. loss :: 8.32e+07
# episode 633: ending balance :: 824516.00, average exp. loss :: 3.68e+06
# syncing network weights...
# episode 634: ending balance :: 803488.63, average exp. loss :: 2.55e+06
# episode 635: ending balance :: 802665.53, average exp. loss :: 3.12e+06
# episode 636: ending balance :: 749686.08, average exp. loss :: 6.20e+05
# episode 637: ending balance :: -1713.52, average exp. loss :: 4.83e+07
# episode 638: ending balance :: -2385.14, average exp. loss :: 1.34e+07
# episode 639: ending balance :: -1676.83, average exp. loss :: 8.18e+06
# episode 640: ending balance :: -338.51, average exp. loss :: 3.10e+06
# episode 641: ending balance :: -119.05, average exp. loss :: 1.75e+07
# episode 642: ending balance :: 750301.60, average exp. loss :: 8.96e+05
# syncing network weights...
# episode 643: ending balance :: 709597.01, average exp. loss :: 4.69e+05
# episode 644: ending balance :: -4981.09, average exp. loss :: 5.31e+07
# episode 645: ending balance :: -3014.52, average exp. loss :: 2.64e+07
# ...
# episode 784: ending balance :: -24524.46, average exp. loss :: 4.55e+07
# episode 785: ending balance :: -2614.50, average exp. loss :: 4.68e+06
# episode 786: ending balance :: -167440.81, average exp. loss :: 1.52e+09
# episode 787: ending balance :: -3309.86, average exp. loss :: 5.21e+06
# episode 788: ending balance :: -202.75, average exp. loss :: 4.14e+06
# syncing network weights...
# episode 789: ending balance :: 367547.42, average exp. loss :: 1.08e+05
# episode 790: ending balance :: -6233.52, average exp. loss :: 7.61e+06
# episode 791: ending balance :: -7097.28, average exp. loss :: 8.70e+06
# episode 792: ending balance :: -34228.01, average exp. loss :: 7.99e+07
# episode 793: ending balance :: -11108.31, average exp. loss :: 1.49e+07
# episode 794: ending balance :: -9367.08, average exp. loss :: 1.29e+07
# episode 795: ending balance :: -8222.04, average exp. loss :: 1.14e+07
# episode 796: ending balance :: -7239.72, average exp. loss :: 1.03e+07
# episode 797: ending balance :: -6450.37, average exp. loss :: 9.41e+06
# episode 798: ending balance :: -5707.61, average exp. loss :: 8.65e+06
# episode 799: ending balance :: 368452.46, average exp. loss :: 1.12e+05
# episode 800: ending balance :: -83370.36, average exp. loss :: 3.97e+08
# episode 801: ending balance :: -4854.27, average exp. loss :: 6.74e+06
# episode 802: ending balance :: -144151.16, average exp. loss :: 1.14e+09
# episode 803: ending balance :: -3820.21, average exp. loss :: 5.84e+06
# episode 804: ending balance :: -12281.12, average exp. loss :: 1.99e+07
# episode 805: ending balance :: -593.30, average exp. loss :: 3.95e+06
# episode 806: ending balance :: 1144549.02, average exp. loss :: 1.44e+08
# episode 807: ending balance :: -14845.62, average exp. loss :: 2.15e+07
# episode 808: ending balance :: -130874.63, average exp. loss :: 9.35e+08
# episode 809: ending balance :: -10268.70, average exp. loss :: 1.42e+07
# episode 810: ending balance :: -790.52, average exp. loss :: 4.05e+06
# syncing network weights...
# episode 811: ending balance :: 371879.34, average exp. loss :: 1.36e+05
# episode 812: ending balance :: -4123.91, average exp. loss :: 5.40e+06
# episode 813: ending balance :: 366879.35, average exp. loss :: 1.15e+05
# episode 814: ending balance :: -7207.77, average exp. loss :: 8.67e+06
# episode 815: ending balance :: -418.71, average exp. loss :: 3.45e+06
# episode 816: ending balance :: -3608.73, average exp. loss :: 8.77e+06
# episode 817: ending balance :: 366717.25, average exp. loss :: 1.13e+05
# episode 818: ending balance :: -63456.11, average exp. loss :: 2.37e+08
# episode 819: ending balance :: -11243.63, average exp. loss :: 1.47e+07
# episode 820: ending balance :: -701.41, average exp. loss :: 3.41e+06
# episode 821: ending balance :: -1230.97, average exp. loss :: 5.57e+06
# syncing network weights...
# episode 822: ending balance :: 373883.62, average exp. loss :: 2.73e+05
# episode 823: ending balance :: -20440.64, average exp. loss :: 3.36e+07
# episode 824: ending balance :: -42292.67, average exp. loss :: 1.14e+08
# episode 825: ending balance :: -9054.85, average exp. loss :: 1.14e+07
# episode 826: ending balance :: -15072.58, average exp. loss :: 2.45e+07
# episode 827: ending balance :: -2407.28, average exp. loss :: 3.55e+06
# episode 828: ending balance :: -20493.51, average exp. loss :: 3.45e+07
# episode 829: ending balance :: -2766.13, average exp. loss :: 4.82e+06
# episode 830: ending balance :: -3155.78, average exp. loss :: 6.55e+06
# episode 831: ending balance :: 825268.82, average exp. loss :: 5.65e+07
# episode 832: ending balance :: -11073.82, average exp. loss :: 1.45e+07
# episode 833: ending balance :: -521061.30, average exp. loss :: 1.39e+10
# episode 834: ending balance :: -12708.00, average exp. loss :: 1.80e+07
# episode 835: ending balance :: -1455.00, average exp. loss :: 4.12e+06
# episode 836: ending balance :: -22819.70, average exp. loss :: 4.82e+07
# episode 837: ending balance :: 371726.67, average exp. loss :: 2.50e+05
# episode 838: ending balance :: -22875.02, average exp. loss :: 4.78e+07
# episode 839: ending balance :: -180.93, average exp. loss :: 3.97e+06
# syncing network weights...
# episode 840: ending balance :: 369509.30, average exp. loss :: 9.91e+04
# episode 841: ending balance :: -223.81, average exp. loss :: 2.63e+06
# episode 842: ending balance :: -70313.67, average exp. loss :: 1.27e+08
# episode 843: ending balance :: -4534.26, average exp. loss :: 5.52e+06
# episode 844: ending balance :: -8462.34, average exp. loss :: 1.04e+07
# episode 845: ending balance :: -310587.89, average exp. loss :: 1.53e+09
# episode 846: ending balance :: -23677.97, average exp. loss :: 4.35e+07
# episode 847: ending balance :: -1659.05, average exp. loss :: 3.47e+06
# episode 848: ending balance :: -2057.81, average exp. loss :: 6.53e+06
# episode 849: ending balance :: 424300.85, average exp. loss :: 1.01e+06
# episode 850: ending balance :: -5083.11, average exp. loss :: 6.23e+06
# episode 851: ending balance :: 369208.08, average exp. loss :: 1.85e+05
# episode 852: ending balance :: -3082.49, average exp. loss :: 4.73e+06
# episode 853: ending balance :: 378356.62, average exp. loss :: 1.93e+05
# episode 854: ending balance :: -3996997.16, average exp. loss :: 8.01e+11
# episode 855: ending balance :: -6319.38, average exp. loss :: 7.82e+06
# episode 856: ending balance :: -1621.11, average exp. loss :: 3.98e+06
# syncing network weights...
# episode 857: ending balance :: 370418.32, average exp. loss :: 2.21e+05
# episode 858: ending balance :: -684.35, average exp. loss :: 2.25e+06
# episode 859: ending balance :: -8451.42, average exp. loss :: 1.01e+07
# episode 860: ending balance :: -47052.11, average exp. loss :: 1.38e+08
# episode 861: ending balance :: -6726.24, average exp. loss :: 8.33e+06
# episode 862: ending balance :: -5871.11, average exp. loss :: 8.00e+06
# episode 863: ending balance :: -1564.70, average exp. loss :: 3.92e+06
# episode 864: ending balance :: -1209.50, average exp. loss :: 4.51e+06
# episode 865: ending balance :: -1158.29, average exp. loss :: 4.50e+06
# episode 866: ending balance :: -1177.08, average exp. loss :: 4.55e+06
# episode 867: ending balance :: 382810.13, average exp. loss :: 4.51e+05
# episode 868: ending balance :: -4881.53, average exp. loss :: 5.79e+06
# episode 869: ending balance :: -130615.94, average exp. loss :: 9.26e+08
# episode 870: ending balance :: -9528.35, average exp. loss :: 1.19e+07
# episode 871: ending balance :: -1790.63, average exp. loss :: 3.94e+06
# episode 872: ending balance :: -1011.30, average exp. loss :: 4.21e+06
# episode 873: ending balance :: -888.60, average exp. loss :: 4.17e+06
# episode 874: ending balance :: 364130.85, average exp. loss :: 1.43e+05
# episode 875: ending balance :: -1479.68, average exp. loss :: 2.80e+06
# episode 876: ending balance :: -12174.34, average exp. loss :: 1.61e+07
# episode 877: ending balance :: -23553.56, average exp. loss :: 4.27e+07
# episode 878: ending balance :: -5396.87, average exp. loss :: 6.94e+06
# syncing network weights...
# episode 879: ending balance :: 361276.66, average exp. loss :: 9.99e+04
# episode 880: ending balance :: -59427.83, average exp. loss :: 2.10e+08
# episode 881: ending balance :: -6207.37, average exp. loss :: 7.71e+06
# episode 882: ending balance :: -1362.42, average exp. loss :: 3.69e+06
# episode 883: ending balance :: -7394.87, average exp. loss :: 1.33e+07
# episode 884: ending balance :: 361694.80, average exp. loss :: 8.93e+04
# episode 885: ending balance :: -4099.62, average exp. loss :: 4.82e+06
# episode 886: ending balance :: -32687.17, average exp. loss :: 7.32e+07
# episode 887: ending balance :: -10732.64, average exp. loss :: 1.39e+07
# episode 888: ending balance :: -2938.05, average exp. loss :: 4.72e+06
# episode 889: ending balance :: 362045.88, average exp. loss :: 1.11e+05
# episode 890: ending balance :: -10339.99, average exp. loss :: 1.29e+07
# episode 891: ending balance :: -29056.10, average exp. loss :: 6.03e+07
# episode 892: ending balance :: -6279.18, average exp. loss :: 7.89e+06
# episode 893: ending balance :: -30.42, average exp. loss :: 2.79e+06
# episode 894: ending balance :: -22036.62, average exp. loss :: 4.49e+07
# episode 895: ending balance :: -709.86, average exp. loss :: 3.09e+06
# episode 896: ending balance :: -379.03, average exp. loss :: 4.15e+06
# syncing network weights...
# episode 897: ending balance :: 361625.19, average exp. loss :: 1.09e+05
# episode 898: ending balance :: -12431.99, average exp. loss :: 1.61e+07
# episode 899: ending balance :: -45480.67, average exp. loss :: 1.29e+08
# episode 900: ending balance :: -4519.67, average exp. loss :: 5.84e+06
# episode 901: ending balance :: 362212.31, average exp. loss :: 1.03e+05
# episode 902: ending balance :: -25390.80, average exp. loss :: 4.75e+07
# episode 903: ending balance :: -2926.83, average exp. loss :: 4.68e+06
# episode 904: ending balance :: 363303.27, average exp. loss :: 1.13e+05
# episode 905: ending balance :: -29372.57, average exp. loss :: 6.10e+07
# episode 906: ending balance :: -10521.28, average exp. loss :: 1.35e+07
# episode 907: ending balance :: -2504.56, average exp. loss :: 4.36e+06
# episode 908: ending balance :: 361466.26, average exp. loss :: 1.41e+05
# episode 909: ending balance :: -1706.65, average exp. loss :: 2.77e+06
# episode 910: ending balance :: -9509.92, average exp. loss :: 1.13e+07
# episode 911: ending balance :: -100454.53, average exp. loss :: 5.59e+08
# episode 912: ending balance :: -3725.85, average exp. loss :: 4.98e+06
# episode 913: ending balance :: -3967.66, average exp. loss :: 6.10e+06
# syncing network weights...
# episode 914: ending balance :: 351647.32, average exp. loss :: 1.21e+05
# episode 915: ending balance :: -9476.22, average exp. loss :: 1.01e+07
# episode 916: ending balance :: 407719.94, average exp. loss :: 1.75e+06
# episode 917: ending balance :: 351547.71, average exp. loss :: 1.09e+05
# syncing network weights...
# episode 918: ending balance :: 349926.90, average exp. loss :: 8.68e+04
# episode 919: ending balance :: -2440.32, average exp. loss :: 5.22e+06
# episode 920: ending balance :: 349971.46, average exp. loss :: 8.91e+04
# episode 921: ending balance :: -10471.83, average exp. loss :: 1.03e+07
# episode 922: ending balance :: -53032.69, average exp. loss :: 6.46e+07
# episode 923: ending balance :: -7426.55, average exp. loss :: 7.67e+06
# episode 924: ending balance :: 351197.32, average exp. loss :: 1.12e+05
# syncing network weights...
# episode 925: ending balance :: 367008.76, average exp. loss :: 3.70e+05
# episode 926: ending balance :: 357005.41, average exp. loss :: 1.53e+05
# episode 927: ending balance :: 353605.58, average exp. loss :: 9.26e+04
# episode 928: ending balance :: -1614.92, average exp. loss :: 4.71e+06
# syncing network weights...
# episode 929: ending balance :: 349906.64, average exp. loss :: 9.14e+04
# episode 930: ending balance :: -611243.47, average exp. loss :: 5.31e+09
# episode 931: ending balance :: 458136.91, average exp. loss :: 2.89e+06
# episode 932: ending balance :: -1341.59, average exp. loss :: 4.45e+06
# episode 933: ending balance :: 372643.47, average exp. loss :: 3.33e+05
# episode 934: ending balance :: 353345.68, average exp. loss :: 1.05e+05
# syncing network weights...
# episode 935: ending balance :: 353988.49, average exp. loss :: 9.82e+04
# episode 936: ending balance :: 351016.63, average exp. loss :: 8.28e+04
# episode 937: ending balance :: 384017.38, average exp. loss :: 6.45e+05
# syncing network weights...
# episode 938: ending balance :: 352003.86, average exp. loss :: 1.03e+05
# episode 939: ending balance :: 354061.51, average exp. loss :: 8.52e+04
# episode 940: ending balance :: 355324.05, average exp. loss :: 8.95e+04
# syncing network weights...
# episode 941: ending balance :: 353759.29, average exp. loss :: 8.86e+04
# episode 942: ending balance :: 366570.16, average exp. loss :: 2.12e+05
# episode 943: ending balance :: 356446.38, average exp. loss :: 1.09e+05
# episode 944: ending balance :: 397709.73, average exp. loss :: 1.46e+06
# episode 945: ending balance :: -2167.51, average exp. loss :: 3.11e+06
# episode 946: ending balance :: -41192.75, average exp. loss :: 2.07e+08
# episode 947: ending balance :: -3798.98, average exp. loss :: 9.76e+06
# syncing network weights...
# episode 948: ending balance :: 361839.84, average exp. loss :: 1.36e+05
# episode 949: ending balance :: 357860.19, average exp. loss :: 1.26e+05
# episode 950: ending balance :: 385675.77, average exp. loss :: 4.24e+05
# episode 951: ending balance :: -2982.32, average exp. loss :: 3.35e+06
# episode 952: ending balance :: -39186.63, average exp. loss :: 1.90e+08
# episode 953: ending balance :: -4012.27, average exp. loss :: 1.02e+07
# episode 954: ending balance :: -1369.28, average exp. loss :: 5.79e+06
# episode 955: ending balance :: -15262.47, average exp. loss :: 9.99e+06
# episode 956: ending balance :: -21765.62, average exp. loss :: 7.28e+07
# episode 957: ending balance :: -6991.87, average exp. loss :: 1.67e+07
# episode 958: ending balance :: -2267.60, average exp. loss :: 7.12e+06
# episode 959: ending balance :: -69.28, average exp. loss :: 4.05e+06
# episode 960: ending balance :: -1394.35, average exp. loss :: 3.11e+06
# episode 961: ending balance :: -39875.57, average exp. loss :: 1.96e+08
# episode 962: ending balance :: -1272.13, average exp. loss :: 5.58e+06
# episode 963: ending balance :: -59511.08, average exp. loss :: 6.81e+07
# episode 964: ending balance :: -7923.16, average exp. loss :: 1.90e+07
# episode 965: ending balance :: -8484.29, average exp. loss :: 5.80e+06
# episode 966: ending balance :: -26987.40, average exp. loss :: 1.02e+08
# episode 967: ending balance :: -1060.10, average exp. loss :: 5.25e+06
# episode 968: ending balance :: -498328.81, average exp. loss :: 3.51e+09
# episode 969: ending balance :: -6591.43, average exp. loss :: 1.56e+07
# episode 970: ending balance :: -2280.65, average exp. loss :: 7.09e+06
# episode 971: ending balance :: -122.63, average exp. loss :: 4.07e+06
# episode 972: ending balance :: -86467.00, average exp. loss :: 1.33e+08
# episode 973: ending balance :: -4817.69, average exp. loss :: 1.17e+07
# episode 974: ending balance :: -44269.93, average exp. loss :: 4.38e+07
# episode 975: ending balance :: -4017.54, average exp. loss :: 1.01e+07
# episode 976: ending balance :: -1098.91, average exp. loss :: 5.35e+06
# episode 977: ending balance :: -4927.29, average exp. loss :: 4.33e+06
# episode 978: ending balance :: -1790.86, average exp. loss :: 6.32e+06
# episode 979: ending balance :: -6043.77, average exp. loss :: 4.50e+06
# episode 980: ending balance :: -2626.10, average exp. loss :: 7.62e+06
# episode 981: ending balance :: -329.38, average exp. loss :: 4.33e+06
# episode 982: ending balance :: -188380.62, average exp. loss :: 5.45e+08
# episode 983: ending balance :: -5560.92, average exp. loss :: 1.33e+07
# episode 984: ending balance :: -27637.45, average exp. loss :: 2.21e+07
# episode 985: ending balance :: -4853.51, average exp. loss :: 1.18e+07
# episode 986: ending balance :: -4254.00, average exp. loss :: 4.48e+06
# episode 987: ending balance :: -7005.70, average exp. loss :: 1.67e+07
# episode 988: ending balance :: -204846.92, average exp. loss :: 6.34e+08
# episode 989: ending balance :: -34114.40, average exp. loss :: 1.50e+08
# episode 990: ending balance :: -1115.39, average exp. loss :: 5.34e+06
# episode 991: ending balance :: -8168.62, average exp. loss :: 5.81e+06
# episode 992: ending balance :: -8047.35, average exp. loss :: 1.93e+07
# episode 993: ending balance :: -10730.66, average exp. loss :: 7.51e+06
# episode 994: ending balance :: -5549.41, average exp. loss :: 1.33e+07
# episode 995: ending balance :: -1838.60, average exp. loss :: 6.42e+06
# syncing network weights...
# episode 996: ending balance :: 344961.59, average exp. loss :: 9.46e+04
# episode 997: ending balance :: 353894.24, average exp. loss :: 1.07e+05
# episode 998: ending balance :: 358789.85, average exp. loss :: 2.33e+05
# syncing network weights...
# episode 999: ending balance :: 355139.16, average exp. loss :: 1.73e+05
# saving model parameters...

# %% [markdown]
# # VALIDATION/TEST SET EVALUATION

# %%
# load model from file if necessary:
trained_model = DeepQNN().to(device=device)
trained_model.load_state_dict(torch.load('./trained_dqnn.params'))
# Out:
# <All keys matched successfully>

# %%
# comment/uncomment following lines as necessary if using 
# validation or test set. 
# x_test, y_test = util.load_dataset('../data/xy_valid_data.csv', True)
x_test, y_test = util.load_dataset('../data/xy_test_data.csv', True)

balance = 1000

preds = []
picks = []

for entry_idx in range(len(x_test)):
    # extract entry:
    curr_state, curr_lbl = x_test[entry_idx], y_test[entry_idx]
    final_winner_odds = curr_state[-1] if curr_lbl == 1 else curr_state[N_ODDS_PER_TEAM - 1]
    
    # compute q-vals & normalize for probs:
    curr_state = np.append(curr_state, [balance])
    curr_state = torch.from_numpy(curr_state).to(device)
    
    q_vals = trained_model(curr_state.float()).cpu().data.numpy()
    
    tot = sum(q_vals)
    pred_probs = [q_val / tot for q_val in q_vals]
    
    # identify the bet-upon team: 
    pred_team = np.argmax(pred_probs)
        
    # extract associated `pred_prob``:
    pred_prob = pred_probs[pred_team]

    # REWARD: compute reward (i.e., winnings/losings) depending on 
    # `pred_prob` and whether `pred_team` == `curr_lbl`:   
    reward = 0
    pred_multiplier = (pred_prob - 0.5) / 0.5 if pred_prob >= 0.5 else -1 * (pred_prob - 0.5) / 0.5
    
    if pred_team == curr_lbl: 
        winnings = final_winner_odds * pred_multiplier if final_winner_odds >= 0 else 100 * pred_multiplier
        reward   = winnings
        balance += winnings  
    else: 
        losings  = 100 * pred_multiplier if final_winner_odds >= 0 else abs(final_winner_odds) * pred_multiplier
        reward   = -1 * losings
        balance -= losings
    
    preds.append(pred_prob)
    picks.append(pred_team)

# %%
# convert picks from 0/1 to 'home'/'away':
picks = ['away' if pick == 1. else 'home' for pick in picks]

# %%
# re-map probs. if pick is home to maintain prob. multiplier 
# computation code as defined for logreg model:
for idx, (pred, pick) in enumerate(zip(preds, picks)): 
    if pick == 'home': 
        preds[idx] = (preds[idx] - 1) / -2

# %%
test = pd.read_csv('../data/test_data.csv')

# add `probs` column to dataframe:
test['preds'] = preds

# add the picks column to the dataframe:
test['strategy_picks'] = picks

# data preview:
test.head(5)
# Out:
#    home_avg_odds_hr_0  home_avg_odds_hr_1  home_avg_odds_hr_2  \
# 0               110.0              -110.0               100.0
# 1              -200.0              -200.0              -200.0
# 2               160.0               140.0               140.0
# 3              -190.0              -190.0              -180.0
# 4              -140.0              -140.0              -140.0
#
#    home_avg_odds_hr_3  home_avg_odds_hr_4  home_avg_odds_hr_5  \
# 0               110.0               110.0               110.0
# 1              -200.0              -190.0              -160.0
# 2               140.0               140.0               140.0
# 3              -180.0              -170.0              -170.0
# 4              -140.0              -140.0              -140.0
#
#    home_avg_odds_hr_6  home_avg_odds_hr_7  home_avg_odds_hr_8  \
# 0               110.0               110.0               110.0
# 1              -150.0              -170.0              -200.0
# 2               140.0               140.0               140.0
# 3              -170.0              -170.0              -180.0
# 4              -150.0              -140.0              -140.0
#
#    home_avg_odds_hr_9  ...  away_avg_odds_hr_68  away_avg_odds_hr_69  \
# 0               110.0  ...                190.0                190.0
# 1              -200.0  ...                280.0                270.0
# 2               140.0  ...                150.0                150.0
# 3              -190.0  ...                420.0                420.0
# 4              -140.0  ...                400.0                400.0
#
#    away_avg_odds_hr_70  away_avg_odds_hr_71  winner  favorite  \
# 0                190.0                190.0    away      home
# 1                270.0                280.0    home      home
# 2                140.0                140.0    away      away
# 3                420.0                400.0    home      home
# 4                400.0                400.0    home      home
#
#    has_favorite_for_winner  closely_contested     preds  strategy_picks
# 0                    False               True -0.015206            home
# 1                     True              False -0.855825            home
# 2                    False               True  0.032416            home
# 3                     True              False -0.655589            home
# 4                     True              False -0.819306            home
#
# [5 rows x 150 columns]

# %%
# drop any unnecessary columns: 
test = test[['home_avg_odds_hr_71', 'away_avg_odds_hr_71', 'winner', 'favorite', 'has_favorite_for_winner', 'closely_contested', 'strategy_picks', 'preds']]

# create a winner_avg_odds column: 
test['winner_avg_odds_hr_71'] = np.where(
    test['winner'] == 'home', test['home_avg_odds_hr_71'], test['away_avg_odds_hr_71']
)

# create 'relative_underdog' column: 
test['relative_underdog'] = np.where(
    test['favorite'] == 'home', 'away', 'home'
)

# %%
N_PROFITABLE_BETS = 0
N_TOTAL_BETS      = 0

NET_VALUE_OF_BETS_WON  = []
NET_VALUE_OF_BETS_LOST = []

UNDERDOG_BETS_HITS  = []
N_UNDERDOG_BETS_TOTAL = 0

CLEAR_WINNER_BETS_HITS = []
N_CLEAR_WINNER_BETS_TOTAL = 0

CLOSELY_CONTESTED_BETS_HITS = []
N_CLOSELY_CONTESTED_BETS_TOTAL = 0

balance = 1000

# iterate through dataframe: 
for row in test.itertuples(index=False):
    
    # if there is balance remaining: 
    if balance >= 0:
    
        # extract elements: 
        final_home_odds, final_away_odds, winner, favorite, has_favorite_for_winner, \
            closely_contested, strategy_pick, pred_prob, final_winner_odds, relative_underdog = row
        
         # update counts:
        if has_favorite_for_winner: N_CLEAR_WINNER_BETS_TOTAL += 1
        if closely_contested: N_CLOSELY_CONTESTED_BETS_TOTAL += 1
        
        # compute `pred` multiplier:
        # if betting on away (pred = [0.5, 1.0]), mulitplier = (pred - 0.5) / 0.5
        # if betting on home (pred = [0.0, 0.5)), multiplier = -1 * (pred - 0.5) / 0.5
        if pred_prob >= 0.5:
            pred_multiplier = (pred_prob - 0.5) / 0.5
        else: 
            pred_multiplier = -1 * (pred_prob - 0.5) / 0.5
        
        # if strategy bet on underdog: 
        if strategy_pick == relative_underdog: 
            N_UNDERDOG_BETS_TOTAL += 1
        
        # if pick was correct: 
        if winner == strategy_pick:
            N_PROFITABLE_BETS += 1
            
            if final_winner_odds >= 0: 
                NET_VALUE_OF_BETS_WON.append(final_winner_odds * pred_multiplier)
            if final_winner_odds < 0:
                NET_VALUE_OF_BETS_WON.append(100 * pred_multiplier)
            
            # if strategy correctly bet on underdog:
            if strategy_pick == relative_underdog:
                if final_winner_odds >= 0: 
                    UNDERDOG_BETS_HITS.append(final_winner_odds * pred_multiplier)
                if final_winner_odds < 0:
                    UNDERDOG_BETS_HITS.append(100 * pred_multiplier)
                    
            # if the strategy correctly bet in a 'clear winner' match:
            if has_favorite_for_winner:
                if final_winner_odds >= 0: 
                    CLEAR_WINNER_BETS_HITS.append(final_winner_odds * pred_multiplier)
                if final_winner_odds < 0:
                    CLEAR_WINNER_BETS_HITS.append(100 * pred_multiplier)
                    
            # if the strategy correctly bet in a 'closely contested' match:
            if closely_contested: 
                if final_winner_odds >= 0: 
                    CLOSELY_CONTESTED_BETS_HITS.append(final_winner_odds * pred_multiplier)
                if final_winner_odds < 0:
                    CLOSELY_CONTESTED_BETS_HITS.append(100 * pred_multiplier) 
                    
            # update balance: 
            if final_winner_odds >= 0: 
                balance += final_winner_odds * pred_multiplier
            if final_winner_odds < 0:
                balance += 100  * pred_multiplier
                                
        # if the pick was incorrect:
        elif winner != strategy_pick:
            if final_winner_odds >= 0: 
                NET_VALUE_OF_BETS_LOST.append(100 * pred_multiplier)
            if final_winner_odds < 0:
                NET_VALUE_OF_BETS_LOST.append(abs(final_winner_odds) * pred_multiplier)
                
            # update balance: 
            if final_winner_odds >= 0: 
                balance -= 100 * pred_multiplier
            if final_winner_odds < 0:
                balance -= abs(final_winner_odds) * pred_multiplier
                
        # update total bet count:
        N_TOTAL_BETS += 1

# %%
# test: removing an outlier.
NET_VALUE_OF_BETS_WON.remove(max(NET_VALUE_OF_BETS_WON))

# %%
profitable_bet_rate       = N_PROFITABLE_BETS / N_TOTAL_BETS
overall_profit            = sum(NET_VALUE_OF_BETS_WON) - sum(NET_VALUE_OF_BETS_LOST)
largest_amt_won           = max(NET_VALUE_OF_BETS_WON)
smallest_amt_won          = min(NET_VALUE_OF_BETS_WON)
avg_amt_won               = sum(NET_VALUE_OF_BETS_WON) / len(NET_VALUE_OF_BETS_WON)
avg_amt_loss              = sum(NET_VALUE_OF_BETS_LOST) / len(NET_VALUE_OF_BETS_LOST)

underdog_bet_hr           = len(UNDERDOG_BETS_HITS) / N_UNDERDOG_BETS_TOTAL  if (N_UNDERDOG_BETS_TOTAL > 0) else 'no underdog bets made.'
avg_underdog_hit_winnings = sum(UNDERDOG_BETS_HITS) / len(UNDERDOG_BETS_HITS) if len(UNDERDOG_BETS_HITS) > 0 else 'no winning underdog bets made.'

clearwinner_bet_hr           = len(CLEAR_WINNER_BETS_HITS) / N_CLEAR_WINNER_BETS_TOTAL  if (N_CLEAR_WINNER_BETS_TOTAL > 0) else 'no clear favorite bets made.'
avg_clearwinner_hit_winnings = sum(CLEAR_WINNER_BETS_HITS) / len(CLEAR_WINNER_BETS_HITS) if len(CLEAR_WINNER_BETS_HITS) > 0 else 'no winning clear favorite bets made.'

closelycontested_bet_hr           = len(CLOSELY_CONTESTED_BETS_HITS) / N_CLOSELY_CONTESTED_BETS_TOTAL  if (N_CLOSELY_CONTESTED_BETS_TOTAL > 0) else 'no closely contested bets made.'
avg_closelycontested_hit_winnings = sum(CLOSELY_CONTESTED_BETS_HITS) / len(CLOSELY_CONTESTED_BETS_HITS) if len(CLOSELY_CONTESTED_BETS_HITS) > 0 else 'no winning closely contested bets made.'


metrics = {
    'profitable_bet_rate' : f'{profitable_bet_rate:.2f} ({N_PROFITABLE_BETS} / {N_TOTAL_BETS})',
    'overall_profit' : overall_profit,
    'largest_amt_won' : largest_amt_won,
    'smallest_amt_won' : smallest_amt_won,
    'avg_amt_won' : avg_amt_won,
    'avg_amt_loss' : avg_amt_loss,
    'underdog_bet_hr' : underdog_bet_hr, 
    'avg_underdog_hit_winnings' : avg_underdog_hit_winnings, 
    'clearwinner_bet_hr' : clearwinner_bet_hr,
    'avg_clearwinner_hit_winnings' : avg_clearwinner_hit_winnings,
    'closelycontested_bet_hr' : closelycontested_bet_hr,
    'avg_closelycontested_hit_winnings' : avg_closelycontested_hit_winnings
}

# report metrics
for metric in metrics.keys():    
    if type(metrics[metric]) is str: 
        print(f'{metric} :: {metrics[metric]}')
    else: 
        print(f'{metric} :: {metrics[metric]:.2f}')
# Out:
# profitable_bet_rate :: 0.59 (586 / 1000)
# overall_profit :: 34456.91
# largest_amt_won :: 1088.89
# smallest_amt_won :: 106.71
# avg_amt_won :: 166.87
# avg_amt_loss :: 152.57
# underdog_bet_hr :: 0.34
# avg_underdog_hit_winnings :: 287.10
# clearwinner_bet_hr :: 0.68
# avg_clearwinner_hit_winnings :: 2230.59
# closelycontested_bet_hr :: 0.51
# avg_closelycontested_hit_winnings :: 171.67
