# %% [markdown]
# # IMPORTS

# %%
import time 

import random as rd
import pandas as pd 
import numpy  as np
import util 

import torch
import torch.nn as nn 
import torch.nn.functional as F

# %% [markdown]
# # CONSTANTS

# %%
NUM_INPUTS       = 144 + 1  # num. network inputs.
NUM_OUTPUTS      = 2        # num. network outputs (1 per state, i.e. bet home/away).
N_ODDS_PER_TEAM  = 72       # num. odds figures per team. 
eta              = 1e-3     # optimizer learning rate.
discount_factor  = 0.95     # discount factor for rl update.
max_train_eps    = 1000     # max. number of training episodes. 
num_exps_to_copy = 20000    # num. exps. per train/target network sync.

# %% [markdown]
# # NEURAL NETWORK CLASS

# %%
# class to represent the deep, fully-connected neural network: 
class DeepQNN(nn.Module): 
    def __init__(self):
        super().__init__()
        # instantiate the model, which consists of a three layer 
        # (input-hidden-output) structure. 
        self.ll1 = nn.Linear(NUM_INPUTS, NUM_INPUTS)
        self.ll2 = nn.Linear(NUM_INPUTS, NUM_OUTPUTS)
        
        # initialize layers: 
        nn.init.xavier_uniform_(self.ll1.weight)
        nn.init.xavier_uniform_(self.ll2.weight)
    
    def forward(self, state):
        x1  = F.relu(self.ll1(state))
        out = self.ll2(x1)
        return out

# %% [markdown]
# # DATA

# %%
# load data:
x_train, y_train = util.load_dataset('../data/logreg_train_data.csv')

# state generator function: 
def get_curr_and_next_state():
    # track idx: 
    idx = 0
    while idx < len(x_train):
        # get current state and final winner odds: 
        curr_state, curr_lbl = x_train[idx], y_train[idx]
        final_winner_odds = curr_state[-1] if curr_lbl == 1 else curr_state[N_ODDS_PER_TEAM - 1]
        # get some random next state, it doesn't matter: 
        rd.seed(229)
        next_state_idx = rd.randint(0, len(x_train) - 1)
        next_state, next_lbl = x_train[next_state_idx], y_train[next_state_idx]
        # yield result: 
        yield (curr_state, next_state, curr_lbl, next_lbl, final_winner_odds)
        # increment the index: 
        idx += 1  
    
# ex. of how to use the generator: 
# state_gen = get_curr_and_next_state()
# curr_state, next_state, curr_lbl, next_lbl = next(state_gen)

# %% [markdown]
# # TRAINING LOOP SET-UP

# %%
# take over any available gpus: 
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# init. the networks. convert to float. 
train_net, target_net = DeepQNN().to(device).float(), DeepQNN().to(device).float()

# init. optimizer: 
optimizer = torch.optim.SGD(train_net.parameters(), lr=eta)

# init. loss fn: 
loss_fn = nn.MSELoss()

# track total experiences: 
num_exps = 0

# %% [markdown]
# # MAIN TRAINING LOOP

# %%
# set epsilon var: 
e = 0.3

# log training time: 
time_start = time.time()

# main training loop: 
for ep_idx in range(max_train_eps):
    
    # refresh loss log, balance, state generator:  
    loss_log = []
    balance = 6000     
    state_gen = get_curr_and_next_state()
    
    # episode concludes when balance <= 0 or all training states visited: 
    while (balance > 0):
        
        # acquire next state: 
        curr_state, next_state, curr_lbl, next_lbl, final_winner_odds = next(state_gen, (None, None, None, None, None))
        
        # only proceed with training if next training state is
        # non-visited (i.e., != None): 
        if curr_state is not None: 
            
            # STATE: concatenate the balance to `curr_state` to make the 
            # complete state vector and convert to tensor:
            curr_state = np.append(curr_state, [balance])
            curr_state = torch.from_numpy(curr_state).to(device)
            
            # ACTION: generate action (i.e., team to bet on and assoc. 
            # pred. prob from 0 to 1) for this state using `target_net`:
            
            # first compute q-val of each action (i.e., logits for betting
            # home or away, output from sigmoid): 
            q_vals = target_net(curr_state.float()).cpu().data.numpy()
            
            # normalize q-vals to produce prediction probabilities: 
            tot = sum(q_vals)
            pred_probs = [q_val / tot for q_val in q_vals]
            
            # identify the bet-upon team: 
            pred_team = np.argmax(pred_probs)
            
            # apply epsilon-greedy: 
            epsilon_prob = np.random.uniform()
            if epsilon_prob < e: 
                pred_team = rd.randint(0, 1)
            
            # extract associated `pred_prob``:
            pred_prob = pred_probs[pred_team]
        
            # REWARD: compute reward (i.e., winnings/losings) depending on 
            # `pred_prob` and whether `pred_team` == `curr_lbl`:   
            reward = 0
            pred_multiplier = (pred_prob - 0.5) / 0.5 if pred_prob >= 0.5 else -1 * (pred_prob - 0.5) / 0.5
            
            if pred_team == curr_lbl: 
                winnings = final_winner_odds * pred_multiplier if final_winner_odds >= 0 else 100 * pred_multiplier
                reward   = winnings
                balance += winnings  
            else: 
                losings  = 100 * pred_multiplier if final_winner_odds >= 0 else abs(final_winner_odds) * pred_multiplier
                reward   = -1 * losings
                balance -= winnings
            
            # NEXT STATE: concatenate the updated balance to the next
            # state array and convert to tensor: 
            next_state = np.append(next_state, [balance])
            next_state = torch.from_numpy(next_state).to(device)
            
            # STATE TERMINAL: state is terminal if balance <= 0:
            terminal = 1 if balance <= 0 else 0 
            
            # UPDATE NETWORK WEIGHTS: determine max q-value assoc. with
            # next state and use as target value for q-update. 
            
            # re-compute q-vals for current episode: 
            q_vals = train_net(curr_state.float())
            
            # compute the maximum q-vals for next state: 
            max_sp_q_val = target_net(next_state.float()).max(-1).values 
            
            # compute the q-update target value:
            targets = reward + (1 - terminal) * discount_factor * max_sp_q_val
            
            # update the q-values to only retain those corresponding to 
            # the executed action (i.e., which team was bet upon): 
            action_mask = F.one_hot(torch.tensor(np.array([pred_team], dtype='int64'), device=device), num_classes=2)
            # apply mask and collapse tensor for scalar comps: 
            q_vals = (action_mask * q_vals).sum(-1) 
             
            # compute loss and backprop! 
            loss = loss_fn(q_vals, targets.detach().view(1))
            optimizer.zero_grad()
            loss.backward()
            # clip gradients to prevent exploding loss:
            torch.nn.utils.clip_grad_norm_(train_net.parameters(), 1.)
            optimizer.step()
            
            # record loss: 
            loss_log.append(loss)
            
            # update experience count: 
            num_exps += 1 
            
            # copy training network weights to target network if 
            # `num_exps_to_copy` reached: 
            if num_exps % num_exps_to_copy == 0: 
                print('syncing network weights...')
                target_net.load_state_dict(train_net.state_dict())
        
        # if all training states visited, break current loop:  
        else:     
            break 
    
    # report episode count, final balance, avg. loss:
    print(f'episode {ep_idx}: ending balance :: {balance:.2f}, average exp. loss :: {sum(loss_log) / len(loss_log):.2e}')
    
    # decay epsilon before next training episode if it is still above 
    # some threshold: 
    if e > 0.05:
        e -= -0.001
            
# log training end time: 
time_end = time.time() 
print(f'training complete! took approx. {round((time_end - time_start) / 60, 2):.3f} minutes.')

# save model parameters: 
print('saving model parameters...')
torch.save(target_net.state_dict(), './trained_dqnn.params')
# Out:
# episode 0: ending balance :: -20776.80, average exp. loss :: 1.24e+06
# episode 1: ending balance :: -1059.25, average exp. loss :: 2.27e+05
# episode 2: ending balance :: -273.47, average exp. loss :: 5.38e+03
# episode 3: ending balance :: -273.47, average exp. loss :: 4.82e+03
# episode 4: ending balance :: -589.06, average exp. loss :: 1.81e+05
# episode 5: ending balance :: -11.28, average exp. loss :: 5.55e+05
# episode 6: ending balance :: -10.95, average exp. loss :: 3.70e+04
# episode 7: ending balance :: -1054.24, average exp. loss :: 1.58e+05
# episode 8: ending balance :: -13886.14, average exp. loss :: 5.72e+06
# episode 9: ending balance :: -1108.82, average exp. loss :: 6.06e+07
# episode 10: ending balance :: -17.28, average exp. loss :: 2.89e+05
# episode 11: ending balance :: -1492.88, average exp. loss :: 6.05e+04
# episode 12: ending balance :: -11.05, average exp. loss :: 8.09e+03
# episode 13: ending balance :: 9555.77, average exp. loss :: 8.97e+05
# episode 14: ending balance :: 110273.30, average exp. loss :: 3.05e+06
# syncing network weights...
# episode 15: ending balance :: 116097.55, average exp. loss :: 2.93e+06
# episode 16: ending balance :: 134097.97, average exp. loss :: 4.88e+05
# episode 17: ending balance :: 136958.60, average exp. loss :: 4.77e+05
# episode 18: ending balance :: -5583.20, average exp. loss :: 6.44e+07
# syncing network weights...
# episode 19: ending balance :: 74588.06, average exp. loss :: 6.37e+06
# episode 20: ending balance :: -28.74, average exp. loss :: 4.12e+06
# episode 21: ending balance :: -52987.20, average exp. loss :: 2.81e+08
# episode 22: ending balance :: -64644.96, average exp. loss :: 1.09e+04
# episode 23: ending balance :: -64644.96, average exp. loss :: 9.43e+03
# episode 24: ending balance :: -393.11, average exp. loss :: 3.83e+06
# episode 25: ending balance :: 740631.04, average exp. loss :: 9.59e+07
# episode 26: ending balance :: 53886.80, average exp. loss :: 2.05e+06
# episode 27: ending balance :: -716.36, average exp. loss :: 2.52e+06
# episode 28: ending balance :: -246895.60, average exp. loss :: 1.89e+09
# episode 29: ending balance :: -4382.06, average exp. loss :: 4.37e+06
# episode 30: ending balance :: -3392.90, average exp. loss :: 6.06e+06
# episode 31: ending balance :: -41948.31, average exp. loss :: 8.27e+07
# episode 32: ending balance :: -51309.43, average exp. loss :: 2.00e+04
# episode 33: ending balance :: -51309.43, average exp. loss :: 1.80e+04
# episode 34: ending balance :: -51309.43, average exp. loss :: 1.61e+04
# episode 35: ending balance :: -51309.43, average exp. loss :: 1.43e+04
# episode 36: ending balance :: -984.34, average exp. loss :: 8.14e+06
# episode 37: ending balance :: -752661.39, average exp. loss :: 7.17e+10
# syncing network weights...
# episode 38: ending balance :: 14727.31, average exp. loss :: 6.51e+05
# episode 39: ending balance :: -1015.92, average exp. loss :: 9.37e+05
# episode 40: ending balance :: -2197.78, average exp. loss :: 3.06e+06
# episode 41: ending balance :: -2197.78, average exp. loss :: 3.04e+06
# episode 42: ending balance :: -4485.48, average exp. loss :: 3.79e+06
# episode 43: ending balance :: -2543.16, average exp. loss :: 4.51e+06
# episode 44: ending balance :: -1091.26, average exp. loss :: 1.29e+06
# episode 45: ending balance :: -258.14, average exp. loss :: 1.73e+06
# episode 46: ending balance :: -381.19, average exp. loss :: 6.44e+05
# episode 47: ending balance :: -904.17, average exp. loss :: 1.89e+06
# episode 48: ending balance :: -482.37, average exp. loss :: 3.10e+06
# episode 49: ending balance :: -461.85, average exp. loss :: 1.21e+06
# episode 50: ending balance :: -949.26, average exp. loss :: 1.02e+06
# episode 51: ending balance :: -868.81, average exp. loss :: 3.12e+06
# episode 52: ending balance :: -87.00, average exp. loss :: 3.32e+08
# episode 53: ending balance :: -914.49, average exp. loss :: 1.09e+06
# episode 54: ending balance :: -5928.95, average exp. loss :: 2.64e+06
# episode 55: ending balance :: -4473.12, average exp. loss :: 6.83e+06
# episode 56: ending balance :: -277.87, average exp. loss :: 9.82e+05
# episode 57: ending balance :: -63.16, average exp. loss :: 1.16e+08
# episode 58: ending balance :: -78.10, average exp. loss :: 1.40e+06
# episode 59: ending balance :: -2187.07, average exp. loss :: 2.79e+07
# episode 60: ending balance :: -267.98, average exp. loss :: 4.67e+05
# episode 61: ending balance :: -564.17, average exp. loss :: 1.15e+06
# episode 62: ending balance :: -252.45, average exp. loss :: 7.24e+05
# episode 63: ending balance :: -1015.76, average exp. loss :: 1.88e+06
# episode 64: ending balance :: -10585.46, average exp. loss :: 2.03e+09
# episode 65: ending balance :: -9355.74, average exp. loss :: 6.85e+06
# episode 66: ending balance :: -112.04, average exp. loss :: 1.17e+06
# episode 67: ending balance :: -926.62, average exp. loss :: 7.12e+05
# episode 68: ending balance :: -1458.56, average exp. loss :: 8.80e+05
# episode 69: ending balance :: -1934.36, average exp. loss :: 1.99e+06
# episode 70: ending balance :: -4179.98, average exp. loss :: 1.02e+06
# episode 71: ending balance :: -2535.90, average exp. loss :: 3.07e+06
# episode 72: ending balance :: 162330.51, average exp. loss :: 3.18e+06
# episode 73: ending balance :: -3647.59, average exp. loss :: 5.83e+06
# episode 74: ending balance :: -1376.33, average exp. loss :: 3.00e+06
# episode 75: ending balance :: -1376.33, average exp. loss :: 2.98e+06
# episode 76: ending balance :: -424.22, average exp. loss :: 3.42e+05
# episode 77: ending balance :: -72.31, average exp. loss :: 6.76e+05
# syncing network weights...
# episode 78: ending balance :: 414854.69, average exp. loss :: 5.23e+09
# episode 79: ending balance :: -55.58, average exp. loss :: 5.38e+06
# episode 80: ending balance :: -756.16, average exp. loss :: 1.06e+06
# episode 81: ending balance :: -289.69, average exp. loss :: 1.76e+06
# episode 82: ending balance :: -2456.91, average exp. loss :: 1.51e+06
# episode 83: ending balance :: -62.97, average exp. loss :: 5.07e+06
# episode 84: ending balance :: 528169.44, average exp. loss :: 5.55e+07
# episode 85: ending balance :: -2088.58, average exp. loss :: 1.26e+10
# episode 86: ending balance :: 644914.23, average exp. loss :: 1.17e+07
# episode 87: ending balance :: -1287.54, average exp. loss :: 1.84e+07
# episode 88: ending balance :: -231.99, average exp. loss :: 3.47e+06
# episode 89: ending balance :: -1249.74, average exp. loss :: 3.08e+06
# episode 90: ending balance :: -5892.60, average exp. loss :: 3.46e+06
# episode 91: ending balance :: -1898.18, average exp. loss :: 7.46e+05
# episode 92: ending balance :: -29247.10, average exp. loss :: 7.12e+06
# episode 93: ending balance :: -163.02, average exp. loss :: 8.35e+05
# episode 94: ending balance :: -1333.22, average exp. loss :: 4.82e+06
# episode 95: ending balance :: -5509.76, average exp. loss :: 2.28e+06
# episode 96: ending balance :: -1550.56, average exp. loss :: 2.78e+06
# syncing network weights...
# episode 97: ending balance :: -1585.77, average exp. loss :: 7.24e+06
# episode 98: ending balance :: 581976.19, average exp. loss :: 1.70e+06
# episode 99: ending balance :: 626613.63, average exp. loss :: 1.04e+07
# episode 100: ending balance :: 887494.56, average exp. loss :: 3.79e+07
# syncing network weights...
# episode 101: ending balance :: 336519.60, average exp. loss :: 1.69e+07
# episode 102: ending balance :: -37.36, average exp. loss :: 1.45e+06
# episode 103: ending balance :: 146686.02, average exp. loss :: 3.26e+06
# episode 104: ending balance :: -17453.01, average exp. loss :: 1.06e+08
# episode 105: ending balance :: -18617.94, average exp. loss :: 2.35e+04
# episode 106: ending balance :: -32608.07, average exp. loss :: 2.74e+08
# episode 107: ending balance :: 132284.03, average exp. loss :: 2.42e+07
# syncing network weights...
# episode 108: ending balance :: 137496.31, average exp. loss :: 1.18e+07
# episode 109: ending balance :: 122980.11, average exp. loss :: 4.79e+06
# episode 110: ending balance :: 119507.81, average exp. loss :: 3.47e+08
# syncing network weights...
# episode 111: ending balance :: 389543.34, average exp. loss :: 3.74e+07
# episode 112: ending balance :: 297868.01, average exp. loss :: 8.51e+06
# episode 113: ending balance :: 370464.34, average exp. loss :: 2.40e+07
# episode 114: ending balance :: -42.30, average exp. loss :: 2.38e+06
# episode 115: ending balance :: 313969.19, average exp. loss :: 1.24e+07
# episode 116: ending balance :: -32433.65, average exp. loss :: 1.63e+07
# syncing network weights...
# episode 117: ending balance :: 246316.42, average exp. loss :: 4.70e+06
# episode 118: ending balance :: 183684.21, average exp. loss :: 1.39e+06
# episode 119: ending balance :: 185226.39, average exp. loss :: 1.63e+06
# syncing network weights...
# episode 120: ending balance :: 303829.83, average exp. loss :: 7.90e+06
# episode 121: ending balance :: -8394.78, average exp. loss :: 6.52e+06
# episode 122: ending balance :: -2932.07, average exp. loss :: 2.38e+04
# episode 123: ending balance :: -5299.12, average exp. loss :: 5.14e+06
# episode 124: ending balance :: -5005.13, average exp. loss :: 5.77e+04
# episode 125: ending balance :: 234373.20, average exp. loss :: 1.34e+07
# episode 126: ending balance :: -18916.38, average exp. loss :: 9.41e+07
# episode 127: ending balance :: 335436.16, average exp. loss :: 3.61e+07
# syncing network weights...
# episode 128: ending balance :: 294798.54, average exp. loss :: 9.69e+09
# episode 129: ending balance :: -279.71, average exp. loss :: 2.76e+06
# episode 130: ending balance :: -202.39, average exp. loss :: 4.21e+05
# episode 131: ending balance :: -65.15, average exp. loss :: 2.44e+07
# episode 132: ending balance :: 697738.43, average exp. loss :: 3.37e+08
# episode 133: ending balance :: -4846.56, average exp. loss :: 9.86e+06
# episode 134: ending balance :: -1137.50, average exp. loss :: 6.96e+09
# episode 135: ending balance :: 797366.04, average exp. loss :: 2.78e+07
# episode 136: ending balance :: -1533.98, average exp. loss :: 2.57e+06
# episode 137: ending balance :: 810874.67, average exp. loss :: 2.43e+07
# syncing network weights...
# episode 138: ending balance :: -1005.57, average exp. loss :: 9.01e+07
# episode 139: ending balance :: 376999.22, average exp. loss :: 1.28e+07
# episode 140: ending balance :: -8765.13, average exp. loss :: 6.37e+06
# episode 141: ending balance :: -4605.94, average exp. loss :: 8.18e+04
# episode 142: ending balance :: 387741.89, average exp. loss :: 1.27e+08
# episode 143: ending balance :: -1901.89, average exp. loss :: 7.64e+06
# episode 144: ending balance :: -51422.79, average exp. loss :: 1.04e+08
# episode 145: ending balance :: -6967.14, average exp. loss :: 5.30e+08
# episode 146: ending balance :: -6006.67, average exp. loss :: 5.93e+06
# episode 147: ending balance :: -69.01, average exp. loss :: 5.65e+06
# episode 148: ending balance :: 389153.02, average exp. loss :: 9.63e+07
# syncing network weights...
# episode 149: ending balance :: 2656896.05, average exp. loss :: 1.14e+09
# episode 150: ending balance :: -561.80, average exp. loss :: 3.10e+06
# episode 151: ending balance :: -1850.41, average exp. loss :: 2.52e+07
# episode 152: ending balance :: -26048.60, average exp. loss :: 9.93e+07
# episode 153: ending balance :: 392376.15, average exp. loss :: 2.21e+08
# episode 154: ending balance :: -1805.76, average exp. loss :: 3.83e+07
# episode 155: ending balance :: -579.05, average exp. loss :: 9.00e+06
# episode 156: ending balance :: -8888.62, average exp. loss :: 3.06e+06
# episode 157: ending balance :: -3178.33, average exp. loss :: 2.11e+06
# episode 158: ending balance :: -2049.86, average exp. loss :: 1.18e+05
# episode 159: ending balance :: -1212.44, average exp. loss :: 1.54e+06
# episode 160: ending balance :: 397952.48, average exp. loss :: 2.35e+08
# episode 161: ending balance :: -1642.89, average exp. loss :: 1.34e+06
# episode 162: ending balance :: -15439.59, average exp. loss :: 2.22e+07
# episode 163: ending balance :: -56939.29, average exp. loss :: 1.08e+05
# episode 164: ending balance :: -5596.94, average exp. loss :: 6.78e+06
# syncing network weights...
# episode 165: ending balance :: 915388.29, average exp. loss :: 1.25e+07
# episode 166: ending balance :: -1711.39, average exp. loss :: 1.25e+07
# episode 167: ending balance :: -2275620.82, average exp. loss :: 2.55e+10
# episode 168: ending balance :: -327.75, average exp. loss :: 7.28e+05
# episode 169: ending balance :: -2368.24, average exp. loss :: 2.44e+06
# episode 170: ending balance :: -170.38, average exp. loss :: 1.44e+06
# episode 171: ending balance :: 1073008.57, average exp. loss :: 3.32e+08
# episode 172: ending balance :: 5171089.19, average exp. loss :: 3.15e+09
# syncing network weights...
# episode 173: ending balance :: 808577.54, average exp. loss :: 6.42e+07
# episode 174: ending balance :: -2340.89, average exp. loss :: 4.71e+11
# episode 175: ending balance :: -478.07, average exp. loss :: 1.08e+05
# episode 176: ending balance :: 26772252.84, average exp. loss :: 1.21e+11
# episode 177: ending balance :: -1464.90, average exp. loss :: 4.01e+06
# episode 178: ending balance :: -111.29, average exp. loss :: 8.90e+06
# episode 179: ending balance :: -2980.14, average exp. loss :: 4.86e+06
# episode 180: ending balance :: -7544.29, average exp. loss :: 8.16e+06
# episode 181: ending balance :: 556595.86, average exp. loss :: 5.14e+07
# episode 182: ending balance :: -3521.95, average exp. loss :: 4.82e+06
# episode 183: ending balance :: -8972.80, average exp. loss :: 1.47e+05
# episode 184: ending balance :: -309.64, average exp. loss :: 4.09e+06
# episode 185: ending balance :: -899.80, average exp. loss :: 3.34e+07
# episode 186: ending balance :: -1462.97, average exp. loss :: 2.70e+06
# episode 187: ending balance :: -1320.46, average exp. loss :: 2.59e+04
# episode 188: ending balance :: -1320.46, average exp. loss :: 2.44e+04
# episode 189: ending balance :: -4030.73, average exp. loss :: 5.84e+06
# episode 190: ending balance :: -8561.94, average exp. loss :: 4.99e+06
# episode 191: ending balance :: -6931.94, average exp. loss :: 1.26e+05
# episode 192: ending balance :: -319.77, average exp. loss :: 5.17e+06
# syncing network weights...
# episode 193: ending balance :: 1733089.71, average exp. loss :: 4.37e+08
# episode 194: ending balance :: 185282.36, average exp. loss :: 1.09e+07
# episode 195: ending balance :: -1827.24, average exp. loss :: 3.91e+06
# episode 196: ending balance :: 177842.31, average exp. loss :: 1.47e+08
# syncing network weights...
# episode 197: ending balance :: 1418337.31, average exp. loss :: 3.04e+08
# episode 198: ending balance :: 166497.85, average exp. loss :: 2.46e+07
# episode 199: ending balance :: 165396.99, average exp. loss :: 2.26e+07
# syncing network weights...
# episode 200: ending balance :: 198252.95, average exp. loss :: 8.73e+07
# episode 201: ending balance :: -51.69, average exp. loss :: 1.89e+08
# episode 202: ending balance :: -3114.69, average exp. loss :: 1.29e+07
# episode 203: ending balance :: -1006.45, average exp. loss :: 6.40e+03
# episode 204: ending balance :: -1006.45, average exp. loss :: 5.47e+03
# episode 205: ending balance :: 790991.04, average exp. loss :: 7.71e+07
# episode 206: ending balance :: 223509.35, average exp. loss :: 4.18e+07
# syncing network weights...
# episode 207: ending balance :: 288463.26, average exp. loss :: 3.32e+07
# episode 208: ending balance :: 370332.57, average exp. loss :: 8.64e+06
# episode 209: ending balance :: -4988.48, average exp. loss :: 4.31e+07
# episode 210: ending balance :: -61059.73, average exp. loss :: 7.25e+04
# episode 211: ending balance :: -61059.73, average exp. loss :: 6.90e+04
# episode 212: ending balance :: -61059.73, average exp. loss :: 6.55e+04
# episode 213: ending balance :: 251996.77, average exp. loss :: 9.07e+06
# episode 214: ending balance :: -1172.85, average exp. loss :: 1.53e+08
# episode 215: ending balance :: -5379.44, average exp. loss :: 1.29e+05
# episode 216: ending balance :: -5379.44, average exp. loss :: 1.24e+05
# episode 217: ending balance :: -5379.44, average exp. loss :: 1.20e+05
# episode 218: ending balance :: 307925.63, average exp. loss :: 9.29e+07
# episode 219: ending balance :: -114461.02, average exp. loss :: 8.97e+07
# episode 220: ending balance :: -181738.02, average exp. loss :: 6.66e+04
# syncing network weights...
# episode 221: ending balance :: 1030187.40, average exp. loss :: 4.98e+07
# episode 222: ending balance :: -1153.16, average exp. loss :: 2.50e+07
# episode 223: ending balance :: -4.06, average exp. loss :: 2.78e+06
# episode 224: ending balance :: -1134.90, average exp. loss :: 1.63e+07
# episode 225: ending balance :: -3367.55, average exp. loss :: 1.33e+06
# episode 226: ending balance :: 1322535.91, average exp. loss :: 9.72e+07
# episode 227: ending balance :: -564.75, average exp. loss :: 2.86e+06
# episode 228: ending balance :: -740.18, average exp. loss :: 2.63e+07
# episode 229: ending balance :: 1152123.33, average exp. loss :: 4.25e+07
# syncing network weights...
    
    # identify the bet-upon team: 
    pred_team = np.argmax(pred_probs)
        
    # extract associated `pred_prob``:
    pred_prob = pred_probs[pred_team]

    # REWARD: compute reward (i.e., winnings/losings) depending on 
    # `pred_prob` and whether `pred_team` == `curr_lbl`:   
    reward = 0
    pred_multiplier = (pred_prob - 0.5) / 0.5 if pred_prob >= 0.5 else -1 * (pred_prob - 0.5) / 0.5
    
    if pred_team == curr_lbl: 
        winnings = final_winner_odds * pred_multiplier if final_winner_odds >= 0 else 100 * pred_multiplier
        reward   = winnings
        balance += winnings  
    else: 
        losings  = 100 * pred_multiplier if final_winner_odds >= 0 else abs(final_winner_odds) * pred_multiplier
        reward   = -1 * losings
        balance -= winnings
    
    preds.append(pred_prob)
    picks.append(pred_team)

# %%
# convert to 'home'/'away':
picks = ['away' if pick == 1. else 'home' for pick in picks]

# %%
# re-map probs. 
for idx, (pred, pick) in enumerate(zip(preds, picks)): 
    if pick == 'home': 
        preds[idx] = (preds[idx] - 1) / -2

# %%
test = pd.read_csv('../data/test_data.csv')

# add `probs` column to dataframe:
test['preds'] = preds

# add the picks column to the dataframe:
test['strategy_picks'] = picks

# data preview:
test.head(5)
# Out:
#    home_avg_odds_hr_0  home_avg_odds_hr_1  home_avg_odds_hr_2  \
# 0               110.0              -110.0               100.0
# 1              -200.0              -200.0              -200.0
# 2               160.0               140.0               140.0
# 3              -190.0              -190.0              -180.0
# 4              -140.0              -140.0              -140.0
#
#    home_avg_odds_hr_3  home_avg_odds_hr_4  home_avg_odds_hr_5  \
# 0               110.0               110.0               110.0
# 1              -200.0              -190.0              -160.0
# 2               140.0               140.0               140.0
# 3              -180.0              -170.0              -170.0
# 4              -140.0              -140.0              -140.0
#
#    home_avg_odds_hr_6  home_avg_odds_hr_7  home_avg_odds_hr_8  \
# 0               110.0               110.0               110.0
# 1              -150.0              -170.0              -200.0
# 2               140.0               140.0               140.0
# 3              -170.0              -170.0              -180.0
# 4              -150.0              -140.0              -140.0
#
#    home_avg_odds_hr_9  ...  away_avg_odds_hr_68  away_avg_odds_hr_69  \
# 0               110.0  ...                190.0                190.0
# 1              -200.0  ...                280.0                270.0
# 2               140.0  ...                150.0                150.0
# 3              -190.0  ...                420.0                420.0
# 4              -140.0  ...                400.0                400.0
#
#    away_avg_odds_hr_70  away_avg_odds_hr_71  winner  favorite  \
# 0                190.0                190.0    away      home
# 1                270.0                280.0    home      home
# 2                140.0                140.0    away      away
# 3                420.0                400.0    home      home
# 4                400.0                400.0    home      home
#
#    has_favorite_for_winner  closely_contested     preds  strategy_picks
# 0                    False               True  0.125684            home
# 1                     True              False  0.014892            home
# 2                    False               True  0.012421            home
# 3                     True              False  0.015121            home
# 4                     True              False  0.014643            home
#
# [5 rows x 150 columns]

# %%
# drop any unnecessary columns: 
test = test[['home_avg_odds_hr_71', 'away_avg_odds_hr_71', 'winner', 'favorite', 'has_favorite_for_winner', 'closely_contested', 'strategy_picks', 'preds']]

# create a winner_avg_odds column: 
test['winner_avg_odds_hr_71'] = np.where(
    test['winner'] == 'home', test['home_avg_odds_hr_71'], test['away_avg_odds_hr_71']
)

# create 'relative_underdog' column: 
test['relative_underdog'] = np.where(
    test['favorite'] == 'home', 'away', 'home'
)

# %%
N_PROFITABLE_BETS = 0
N_TOTAL_BETS      = 0

NET_VALUE_OF_BETS_WON  = []
NET_VALUE_OF_BETS_LOST = []

UNDERDOG_BETS_HITS  = []
N_UNDERDOG_BETS_TOTAL = 0

CLEAR_WINNER_BETS_HITS = []
N_CLEAR_WINNER_BETS_TOTAL = 0

CLOSELY_CONTESTED_BETS_HITS = []
N_CLOSELY_CONTESTED_BETS_TOTAL = 0

balance = 1000

# iterate through dataframe: 
for row in test.itertuples(index=False):
    
    # if there is balance remaining: 
    if balance >= 0:
    
        # extract elements: 
        final_home_odds, final_away_odds, winner, favorite, has_favorite_for_winner, \
            closely_contested, strategy_pick, pred_prob, final_winner_odds, relative_underdog = row
            
         # update counts:
        if has_favorite_for_winner: N_CLEAR_WINNER_BETS_TOTAL += 1
        if closely_contested: N_CLOSELY_CONTESTED_BETS_TOTAL += 1
        
        # compute `pred` multiplier:
        # if betting on away (pred = [0.5, 1.0]), mulitplier = (pred - 0.5) / 0.5
        # if betting on home (pred = [0.0, 0.5)), multiplier = -1 * (pred - 0.5) / 0.5
        if pred_prob >= 0.5:
            pred_multiplier = (pred_prob - 0.5) / 0.5
        else: 
            pred_multiplier = -1 * (pred_prob - 0.5) / 0.5
        
        # if strategy bet on underdog: 
        if strategy_pick == relative_underdog: 
            N_UNDERDOG_BETS_TOTAL += 1
        
        # if pick was correct: 
        if winner == strategy_pick:
            N_PROFITABLE_BETS += 1
            
            if final_winner_odds >= 0: 
                NET_VALUE_OF_BETS_WON.append(final_winner_odds * pred_multiplier)
            if final_winner_odds < 0:
                NET_VALUE_OF_BETS_WON.append(100 * pred_multiplier)
            
            # if strategy correctly bet on underdog:
            if strategy_pick == relative_underdog:
                if final_winner_odds >= 0: 
                    UNDERDOG_BETS_HITS.append(final_winner_odds * pred_multiplier)
                if final_winner_odds < 0:
                    UNDERDOG_BETS_HITS.append(100 * pred_multiplier)
                    
            # if the strategy correctly bet in a 'clear winner' match:
            if has_favorite_for_winner:
                if final_winner_odds >= 0: 
                    CLEAR_WINNER_BETS_HITS.append(final_winner_odds * pred_multiplier)
                if final_winner_odds < 0:
                    CLEAR_WINNER_BETS_HITS.append(100 * pred_multiplier)
                    
            # if the strategy correctly bet in a 'closely contested' match:
            if closely_contested: 
                if final_winner_odds >= 0: 
                    CLOSELY_CONTESTED_BETS_HITS.append(final_winner_odds * pred_multiplier)
                if final_winner_odds < 0:
                    CLOSELY_CONTESTED_BETS_HITS.append(100 * pred_multiplier) 
                    
            # update balance: 
            if final_winner_odds >= 0: 
                balance += final_winner_odds * pred_multiplier
            if final_winner_odds < 0:
                balance += 100  * pred_multiplier
                                
        # if the pick was incorrect:
        elif winner != strategy_pick:
            if final_winner_odds >= 0: 
                NET_VALUE_OF_BETS_LOST.append(100 * pred_multiplier)
            if final_winner_odds < 0:
                NET_VALUE_OF_BETS_LOST.append(abs(final_winner_odds) * pred_multiplier)
                
            # update balance: 
            if final_winner_odds >= 0: 
                balance -= 100 * pred_multiplier
            if final_winner_odds < 0:
                balance -= abs(final_winner_odds) * pred_multiplier
                
        # update total bet count:
        N_TOTAL_BETS += 1

# %%
profitable_bet_rate       = N_PROFITABLE_BETS / N_TOTAL_BETS
overall_profit            = sum(NET_VALUE_OF_BETS_WON) - sum(NET_VALUE_OF_BETS_LOST)
largest_amt_won           = max(NET_VALUE_OF_BETS_WON)
smallest_amt_won          = min(NET_VALUE_OF_BETS_WON)
avg_amt_won               = sum(NET_VALUE_OF_BETS_WON) / len(NET_VALUE_OF_BETS_WON)
avg_amt_loss              = sum(NET_VALUE_OF_BETS_LOST) / len(NET_VALUE_OF_BETS_LOST)

underdog_bet_hr           = len(UNDERDOG_BETS_HITS) / N_UNDERDOG_BETS_TOTAL  if (N_UNDERDOG_BETS_TOTAL > 0) else 'no underdog bets made.'
avg_underdog_hit_winnings = sum(UNDERDOG_BETS_HITS) / len(UNDERDOG_BETS_HITS) if len(UNDERDOG_BETS_HITS) > 0 else 'no winning underdog bets made.'

clearwinner_bet_hr           = len(CLEAR_WINNER_BETS_HITS) / N_CLEAR_WINNER_BETS_TOTAL  if (N_CLEAR_WINNER_BETS_TOTAL > 0) else 'no clear favorite bets made.'
avg_clearwinner_hit_winnings = sum(CLEAR_WINNER_BETS_HITS) / len(CLEAR_WINNER_BETS_HITS) if len(CLEAR_WINNER_BETS_HITS) > 0 else 'no winning clear favorite bets made.'

closelycontested_bet_hr           = len(CLOSELY_CONTESTED_BETS_HITS) / N_CLOSELY_CONTESTED_BETS_TOTAL  if (N_CLOSELY_CONTESTED_BETS_TOTAL > 0) else 'no closely contested bets made.'
avg_closelycontested_hit_winnings = sum(CLOSELY_CONTESTED_BETS_HITS) / len(CLOSELY_CONTESTED_BETS_HITS) if len(CLOSELY_CONTESTED_BETS_HITS) > 0 else 'no winning closely contested bets made.'


metrics = {
    'profitable_bet_rate' : f'{profitable_bet_rate:.2f} ({N_PROFITABLE_BETS} / {N_TOTAL_BETS})',
    'overall_profit' : overall_profit,
    'largest_amt_won' : largest_amt_won,
    'smallest_amt_won' : smallest_amt_won,
    'avg_amt_won' : avg_amt_won,
    'avg_amt_loss' : avg_amt_loss,
    'underdog_bet_hr' : underdog_bet_hr, 
    'avg_underdog_hit_winnings' : avg_underdog_hit_winnings, 
    'clearwinner_bet_hr' : clearwinner_bet_hr,
    'avg_clearwinner_hit_winnings' : avg_clearwinner_hit_winnings,
    'closelycontested_bet_hr' : closelycontested_bet_hr,
    'avg_closelycontested_hit_winnings' : avg_closelycontested_hit_winnings
}

# report metrics
for metric in metrics.keys():    
    if type(metrics[metric]) is str: 
        print(f'{metric} :: {metrics[metric]}')
    else: 
        print(f'{metric} :: {metrics[metric]:.2f}')
# Out:
# profitable_bet_rate :: 0.59 (586 / 1000)
# overall_profit :: 24592.08
# largest_amt_won :: 660.70
# smallest_amt_won :: 95.16
# avg_amt_won :: 126.91
# avg_amt_loss :: 120.24
# underdog_bet_hr :: 0.34
# avg_underdog_hit_winnings :: 230.27
# clearwinner_bet_hr :: 0.68
# avg_clearwinner_hit_winnings :: 119.55
# closelycontested_bet_hr :: 0.51
# avg_closelycontested_hit_winnings :: 134.42
